# %% [markdown]
# # DSC 630 - Course Project
# ## Python Data Initial Clean Up Code

# %%
import pandas as pd
import numpy as np
import xlrd
import os
import re

# %%
#read in main files
wb = xlrd.open_workbook("Data\AnimalIntakeWithResultsExtended_2015_2016.xlsx", logfile=open(os.devnull, 'w'))
data20152016 = pd.read_excel(wb, engine='xlrd')

wb = xlrd.open_workbook("Data\AnimalIntakeWithResultsExtended_2017_2018.xlsx", logfile=open(os.devnull, 'w'))
data20172018 = pd.read_excel(wb, engine='xlrd')

wb = xlrd.open_workbook("Data\AnimalIntakeWithResultsExtended_2019.xlsx", logfile=open(os.devnull, 'w'))
data2019 = pd.read_excel(wb, engine='xlrd')

#concatenate the datasets
data_df = pd.concat([data20152016, data20172018, data2019])

del data20152016, data20172018, data2019

data_df.head()
# Out:
#     Animal #       ARN  Animal Name Animal Type Species         Primary Breed  \
# 0  A10338615  LA54918A         Chaz         Dog     Dog             Chow Chow
# 1  A10345450  LA54552A     Snowball         Dog     Dog     Poodle, Miniature
# 2  A10357120  LA57609A  Louise (Lu)         Cat     Cat    Domestic Shorthair
# 3  A10363334  LA54952A        Lucky         Dog     Dog     Poodle, Miniature
# 4  A10363778   LA34139         Zoey         Cat     Cat  Domestic Medium Hair
#
#       Secondary Breed Distinguishing Markings Gender Altered  ...  \
# 0                 Mix                     NaN      M     Yes  ...
# 1                 Mix                     NaN      M     Yes  ...
# 2  Domestic Shorthair                     NaN      F     Yes  ...
# 3                 Mix                     NaN      M     Yes  ...
# 4  Domestic Shorthair                     NaN      F     Yes  ...
#
#   Outcome Agency Name Agency Street Address Agency Unit Number  Agency City  \
# 0                 NaN                   NaN                NaN          NaN
# 1                 NaN                   NaN                NaN          NaN
# 2                 NaN                   NaN                NaN          NaN
# 3                 NaN                   NaN                NaN          NaN
# 4                 NaN                   NaN                NaN          NaN
#
#   Agency Province Agency Postal Code Agency Email Agency Home Phone  \
# 0             NaN                NaN          NaN               NaN
# 1             NaN                NaN          NaN               NaN
# 2             NaN                NaN          NaN               NaN
# 3             NaN                NaN          NaN               NaN
# 4             NaN                NaN          NaN               NaN
#
#   Agency Cell Number RN
# 0                NaN  1
# 1                NaN  1
# 2                NaN  1
# 3                NaN  1
# 4                NaN  1
#
# [5 rows x 87 columns]

# %%
#save merged file
data_df.to_csv('AllIntakeWithResults.csv', index = False)

# %%
data_df.shape
# Out:
# (12729, 87)

# %%
data_df.columns
# Out:
# Index(['Animal #', 'ARN', 'Animal Name', 'Animal Type', 'Species',
#        'Primary Breed', 'Secondary Breed', 'Distinguishing Markings', 'Gender',
#        'Altered', 'Danger', 'Danger Reason', 'Date Of Birth',
#        'Age in Months Intake', 'Age Group', 'Intake Asilomar Status',
#        'Intake Condition', 'Intake Record Owner', 'Intake Date', 'Intake Type',
#        'Intake Subtype', 'Found Address', 'Found Zip Code', 'Reason',
#        'Intake SiteName', 'Jurisdiction In', 'Agency Name', 'Agency Member',
#        'Agency Member Phone', 'Agency Address', 'Intake Person ID',
#        'Intake Person ID Type', 'Intake Person #', 'Admitter',
#        'Street Address', 'Unit Number', 'City', 'Province', 'Postal Code',
#        'Admitter's Email', 'Admitter's Home Phone', 'Admitter's Cell Phone',
#        'Initial Stage', 'Initial Review Date', 'Age in Months Current',
#        'Microchip Issue Date', 'Microchip Provider', 'Microchip Number',
#        'Pet ID', 'Pet ID Type', 'Status', 'Stage', 'Location', 'Sublocation',
#        'Outcome Asilomar Status', 'Outcome Number', 'Released By',
#        'Date Created', 'Outcome Date', 'Release Date', 'Outcome Type',
#        'Outcome Subtype', 'Outcome SiteName', 'Jurisdiction Out',
#        'Outcome Reason', 'Outcome Person ID', 'Outcome Person ID Type',
#        'Outcome Person #', 'Outcome Person Name', 'Out Street Address',
#        'Out Unit Number', 'Out City', 'Out Province', 'Out Postal Code',
#        'Out Email', 'Out Home Phone', 'Out Cell Phone', 'Outcome Agency Name',
#        'Agency Street Address', 'Agency Unit Number', 'Agency City',
#        'Agency Province', 'Agency Postal Code', 'Agency Email',
#        'Agency Home Phone', 'Agency Cell Number', 'RN'],
#       dtype='object')

# %%
#check the difference between type and species
data_df['Species'].unique(), data_df['Species'].notna().sum(), data_df['Species'].describe()
# Out:
# (array(['Dog', 'Cat', 'Rabbit', 'Ferret', 'Lizard', 'Pig', 'Peacock',
#         'Duck', 'Guinea Pig', 'Chicken', 'Hamster', 'Dove', 'Goat',
#         'Parakeet', 'Turkey', 'Fowl', 'Cockatoo', 'Rat', 'Parrot',
#         'Turtle', 'Horse', 'Cockatiel', 'Cattle (Cow)', 'Iguana'],
#        dtype=object),
#  12729,
#  count     12729
#  unique       24
#  top         Dog
#  freq       7235
#  Name: Species, dtype: object)

# %%
data_df['Animal Type'].unique(), data_df['Animal Type'].notna().sum(), data_df['Animal Type'].describe()
# Out:
# (array(['Dog', 'Cat', 'Domestic', 'Reptile', 'Livestock', 'Wild Bird',
#         'Rodent', 'Bird'], dtype=object),
#  12729,
#  count     12729
#  unique        8
#  top         Dog
#  freq       7235
#  Name: Animal Type, dtype: object)

# %%
#since we are only concerned with Dogs and cats both of these fields aren't needed.  I'm going to restrict the data
#to only dogs and cats
data_df = data_df[(data_df['Species'] == 'Dog') |  (data_df['Species'] == 'Cat')]
data_df.shape
# Out:
# (12412, 87)

# %%
# we need to exclude any animals who were adopted after 2/29/2020 to avoid future leakage.
data_df['Outcome Date'] = pd.to_datetime(data_df['Outcome Date'])
data_df = data_df[data_df['Outcome Date'] < pd.Timestamp(2020, 3, 1)]

# %%
#create clean dataset
clean_data = pd.DataFrame()
clean_data['AnimalID'] = data_df['Animal #']
clean_data['Species'] = data_df['Species']

# %%
data_df['Primary Breed'].unique(), data_df['Primary Breed'].notna().sum(), data_df['Primary Breed'].describe()
# Out:
# (array(['Chow Chow', 'Poodle, Miniature', 'Domestic Shorthair',
#         'Domestic Medium Hair', 'Retriever, Labrador',
#         'Terrier, Yorkshire', 'Terrier, Pit Bull',
#         'Spaniel, American Cocker', 'Spaniel', 'Cornish Rex', 'Hound',
#         'Manx', 'Terrier', 'Chihuahua, Short Coat', 'Terrier, Rat',
#         'Dachshund, Standard Smooth Haired', 'Shih Tzu', 'Bullmastiff',
#         'Australian Cattle Dog', 'Bulldog, American', 'Maltese',
#         'Dachshund, Miniature Smooth Haired', 'Griffon, Brussels',
#         'Basenji', 'Retriever', 'Pekingese', 'Shepherd', 'Boxer',
#         'Chihuahua, Long Coat', 'Terrier, Airedale', 'German Shepherd',
#         'Lhasa Apso', 'Siamese', 'Terrier, American Pit Bull', 'Beagle',
#         'Schnauzer, Miniature', 'Domestic Longhair',
#         'Mixed Breed, Large (over 44 lbs fully grown)', 'Pomeranian',
#         'Alaskan Husky', 'Catahoula Leopard dog', 'Welsh Corgi, Pembroke',
#         'Border Collie', 'Rhodesian Ridgeback', 'Terrier, Boston',
#         'Poodle, Toy', 'Weimaraner', 'Dachshund, Miniature Long Haired',
#         'Shiba Inu', 'Siberian Husky', 'Himalayan', 'Terrier, Cairn',
#         'Terrier, Jack Russell', 'Pointer', 'Australian Kelpie',
#         'Swedish Vallhund', 'Rottweiler', 'Schnauzer, Standard',
#         'Australian Shepherd', 'Basset Hound', 'Italian Greyhound',
#         'Bulldog, English', 'Terrier, Fox, Wire', 'Papillon', 'Pug',
#         'Bichon Frise', 'Brittany', 'Alaskan Malamute', 'Spinone Italiano',
#         'Shetland Sheepdog', 'Finnish Spitz', 'Miniature Pinscher',
#         'Dachshund, Standard Long Haired', 'Maine Coon',
#         'Spaniel, Tibetan', 'American Bobtail', 'Havanese', 'Persian',
#         'Terrier, West Highland White', 'Poodle, Standard', 'Mastiff',
#         'Dachshund, Standard Wire Haired', 'Saint Bernard', 'Whippet',
#         'Belgian Malinois', 'Dalmatian', 'Terrier, Staffordshire Bull',
#         'Coonhound, Black and Tan', 'Terrier, American Staffordshire',
#         'Terrier, Norfolk', 'Spaniel, English Cocker', 'Russian Blue',
#         'Spaniel, Cavalier King Charles',
#         'Mixed Breed, Medium (up to 44 lbs fully grown)',
#         'Treeing Tennessee Brindle', 'Dachshund, Miniature Wire Haired',
#         'Terrier, Patterdale', 'Collie, Smooth', 'Terrier, Russell',
#         'Retriever, Golden', 'Bulldog, French', 'Turkish Van',
#         'Vizsla, Smooth Haired', 'Mudi', 'American Eskimo',
#         'Welsh Corgi, Cardigan', 'Abyssinian', 'Carolina Dog', 'Boerboel',
#         'Cur, Black-Mouth', 'Terrier, Dandie Dinmont', 'Great Dane',
#         'Terrier, Bull', 'Bulldog', 'Retriever, Flat-Coated',
#         'Bearded Collie', 'Terrier, Silky', 'Pointer, German Shorthaired',
#         'Spaniel, English Springer', 'Plott Hound',
#         'Terrier, Soft Coated Wheaten', 'Terrier, Scottish', 'Coonhound',
#         'Perro de Presa Canario', 'American Wirehair',
#         'American Blue Heeler', 'Olde English Bulldogge', 'Briard',
#         'Terrier, Skye', 'Terrier, Fox, Toy', 'Akita', 'Angora',
#         'Xoloitzcuintli', 'Terrier, Border', 'Newfoundland', 'Harrier',
#         'Snowshoe', 'Bengal', 'Coonhound, American English',
#         'Terrier, Fox, Smooth', 'Retriever, Chesapeake Bay',
#         'Norwegian Buhund', 'Terrier, Tibetan', 'Doberman Pinscher',
#         'Dutch Shepherd', 'Australian Shepherd, Miniature',
#         'American Shorthair', 'Terrier, Miniature Bull',
#         'Mexican Hairless', 'Lancashire Heeler', 'Bernese Mountain Dog',
#         'Chinese Shar-Pei',
#         'Mixed Breed, Small (under 24 lbs fully grown)', 'Bombay',
#         'Great Pyrenees', 'Schnauzer, Giant', 'Greater Swiss Mountain Dog',
#         'Terrier, Parson Russell', 'Exotic Shorthair', 'Bloodhound',
#         'Collie, Rough', 'Coton de Tulear', 'German Shepherd, King',
#         'Anatolian Shepherd', 'Feist', 'Canaan', 'Cane Corso',
#         'Irish Wolfhound', 'Belgian Tervuren', 'Ragdoll',
#         'Coonhound, Treeing Walker', 'Coonhound, Bluetick',
#         'American White Shepherd', 'Spaniel, English Toy',
#         'Foxhound, American', 'European Shorthair', 'Greyhound'],
#        dtype=object),
#  12372,
#  count                  12372
#  unique                   177
#  top       Domestic Shorthair
#  freq                    4480
#  Name: Primary Breed, dtype: object)

# %%
data_df['Secondary Breed'].unique(), data_df['Secondary Breed'].notna().sum(), data_df['Secondary Breed'].describe()
# Out:
# (array(['Mix', 'Domestic Shorthair', 'Boxer', nan, 'Welsh Corgi, Cardigan',
#         'Retriever', 'Shepherd', 'Terrier, Jack Russell',
#         'Bulldog, American', 'Terrier, Soft Coated Wheaten',
#         'Poodle, Miniature', 'Affenpinscher', 'Terrier', 'Chow Chow',
#         'Terrier, Boston', 'Bulldog', 'Basset Hound',
#         'Rhodesian Ridgeback', 'Maltese', 'Miniature Pinscher',
#         'Terrier, Yorkshire', 'Terrier, Pit Bull', 'Hound',
#         'Chihuahua, Short Coat', 'Dachshund, Standard Smooth Haired',
#         'Rottweiler', 'Retriever, Labrador', 'Italian Greyhound',
#         'Terrier, Scottish', 'Shih Tzu', 'Collie, Smooth',
#         'Terrier, Tibetan', 'Siamese', 'Terrier, Staffordshire Bull',
#         'Retriever, Golden', 'Chihuahua, Long Coat', 'Siberian Husky',
#         'Papillon', 'Dachshund, Miniature Smooth Haired', 'Dalmatian',
#         'Chinese Crested', 'Spaniel', 'Collie, Rough', 'Beagle',
#         'Australian Cattle Dog', 'Bichon Frise', 'Pug',
#         'Catahoula Leopard dog', 'Old English Sheepdog', 'Akita',
#         'Cur, Black-Mouth', 'Maine Coon', 'Mastiff', 'Poodle, Toy',
#         'Terrier, Russell', 'German Shepherd', 'Shetland Sheepdog',
#         'Terrier, American Pit Bull', 'Pointer', 'Australian Kelpie',
#         'Terrier, Rat', 'Pharaoh Hound', 'Terrier, Silky', 'Basenji',
#         'Keeshond', 'Border Collie', 'Whippet', 'Pomeranian',
#         'Terrier, Cairn', 'Briard', 'Persian', 'Lhasa Apso', 'Shiba Inu',
#         'Welsh Corgi, Pembroke', 'Spaniel, Cavalier King Charles',
#         'Griffon, Brussels', 'Schnauzer, Miniature', 'Schnauzer, Standard',
#         'Weimaraner', 'Great Dane', 'Pekingese', 'Australian Shepherd',
#         'Terrier, West Highland White', 'Domestic Longhair', 'Havanese',
#         'Ragdoll', 'Poodle, Standard',
#         'Mixed Breed, Large (over 44 lbs fully grown)',
#         'Anatolian Shepherd', 'Bulldog, English', 'Bullmastiff',
#         'Mixed Breed, Small (under 24 lbs fully grown)',
#         'Retriever, Chesapeake Bay', 'Portuguese Podengo',
#         'Spaniel, American Cocker', 'American Blue Heeler',
#         'Terrier, Fox, Wire', 'Domestic Medium Hair', 'Alaskan Husky',
#         'Great Pyrenees', 'Dachshund, Miniature Long Haired',
#         'Carolina Dog', 'Bulldog, French', 'Dutch Shepherd', 'Canaan',
#         'Abyssinian', 'Dachshund, Miniature Wire Haired',
#         'Terrier, Norfolk', 'Dachshund, Standard Long Haired',
#         'Terrier, Bedlington', 'Terrier, Manchester', 'Himalayan',
#         'Russian Blue', 'Terrier, Fox, Smooth'], dtype=object),
#  11872,
#  count     11872
#  unique      113
#  top         Mix
#  freq      10560
#  Name: Secondary Breed, dtype: object)

# %%
clean_data['PrimaryBreed'] = data_df['Primary Breed']
clean_data['SecondaryBreed'] = data_df['Secondary Breed']

# %%
#view data contained in distinguishing markings
data_df['Distinguishing Markings'].unique(), data_df['Distinguishing Markings'].notna().sum(), data_df['Distinguishing Markings'].describe()

#only 374 records have values, not enough for use in a model.
# Out:
# (array([nan, 'SEVERELY MATTED!', 'wearing Thundershirt when found',
#         'missing hair along back',
#         'Came in with end of tail injured...possibly bitten off',
#         'wound to neck, possibly a cat fight wound',
#         'longer coat, hair in ears',
#         'white spot on lower belly, white hairs on chest',
#         'few white hairs on belly, no white on chest', 'spot on nose',
#         'front leg injury, possible HBC', 'cataracts/eye discharge',
#         'darker of two', 'Brown head, white/grey back',
#         'light brown spots on back', 'black/brindle spots on back',
#         'Largest of litter', 'Smallest of litter', 'Green eyes',
#         'yellow eyes', 'Runny eyes', 'white with black spot on the head',
#         'more white on face', 'hairloss and scabbing on tail, paws',
#         'MATTED COAT', 'WHITE SOCKS',
#         'FINDER CLIPPED DOG&#39;S HAIR/ Right eye is cloudy ',
#         'half of tail missing, appears healed', 'lazy eye', 'Three legs',
#         'White stripe on nose', 'left ear tip', 'Largest. Tiger stripes',
#         'Smallest', 'Right ear tip. No chip',
#         'most white on chest &amp; feet',
#         'missing half of left ear, old injury, not eartip',
#         'cherry (left) eye, greenish discharge coming out of the eye  ',
#         'Left tip (was part of caretaker&#39;s colony). if not adoptable, may be returned to field',
#         'Wrinkled face', 'orange stripe down face',
#         'White toes on hind legs and left front foot',
#         'White boot on front right foot and white toes on all other feet',
#         'Big white boots on front legs and white toes on hind legs',
#         'All black body and toes.  White on chest', 'White dot on nose.',
#         'White dot on chin', 'Vertical white stripe on nose',
#         'White on chin and chest', 'White V on Chest', 'White on nose',
#         'One white spot on the front of her neck and her chest. ',
#         'Small white spot on forehead', 'Orange shoulders', 'White paws',
#         'hair loss on back', 'one crusty eye', 'white toes and tail tip',
#         'White boots all four paws',
#         'Black mask with nose stripe, less white on body',
#         'White stripe across backside',
#         'Black mask with nose stripe, more white on body',
#         'Mostly black face',
#         'front right leg is black, orange, and white. front left leg is black and white. ',
#         'Mostly black with orange accents.', 'VITILIGO',
#         'more black on face ', 'Extra toes on back paws',
#         'front left leg missing/deformed', 'Left ear tip',
#         'multiple wounds all over back/neck', 'Dog is extremely matted.',
#         'fluffy tail', 'sutures seen and shaved abdomen ',
#         'missing toes on front paw, declawed in front ',
#         'scabbing on ear and along back ', 'R ear tip ', 'White mustache',
#         'small lacerations from unlined wire trap.', 'Hairless/Boney tail',
#         'LE Tipped', 'long nails', 'Overweight', 'minor skin issues',
#         'tan on mustache', 'white paws', 'Missing back foot',
#         'clipped nails', 'matted ', 'Spot on nose',
#         'Limping back right leg', 'more tan around left eye patch',
#         'white chest', 'choke chain attached to a broken tether',
#         'front declawed', 'Black mask on face', 'White stripe down nose',
#         'Black spot between shoulders, more timid than her sister. ',
#         'several broken teeth, scarring on face ',
#         'Has some freckly dark markings along body. ', 'polydactyl ',
#         'Brown on nose', 'More white on chin, less on face.',
#         'White stripe on nose.', 'White on chest', 'cloudy eye',
#         'HALF OF LEFT EAR MISSING (OLD INJURY)', 'Left eye infection ',
#         'small rash on lower back.', 'Mostly Black',
#         'equal parts black and white', 'Mostly white. Cut on back leg.',
#         'white spot on chest', 'more white under the chin',
#         'less white under chin',
#         'Fur is slightly  more  grey  than  others', 'bigger one',
#         'smaller one', 'possible ringworm on tail ', 'white on chest',
#         'found in NO East on Crowder Blvd, was adopted from LASPCA, phone number on chip no good',
#         'white moustache', 'right ear tip ', 'White on neck and chest',
#         'White on left rear toe', '1 blue/1 green eye',
#         'White over left eye. ', 'White in between eyes. ',
#         'Right eye different color.', 'matted', 'black dot on lower back ',
#         'white stripe on back through black patch ', 'solid black back',
#         'Ear Tipped', 'black dot on back', 'black spot on face',
#         'Right cherry eye', 'right tip',
#         'more patterned than other tabby in litter',
#         'Grey van markings on ears/tail',
#         'covered in fleas, missing significant hair ', 'very matted',
#         'DECLAWED', '3 legged', 'blind', 'Hair loss around eyes',
#         'Right ear tipped', 'Left ear tipped',
#         'tiny mass on right side of face',
#         'She has black, gold, white, and tan tiger stripes.',
#         'White fur patch on neck. Missing hair on tail.', 'Dark Brown',
#         'Eye Issue', 'white stripe on head', 'Spay tattoo', 'White chest',
#         'White chest, paws, chin , and white stripe down face',
#         'white paws, chest, and white line down snout', 'Eye condition ',
#         'black on ears', 'black mask/muzzle', 'Short blonde fur',
#         'white fur on paws',
#         'Whit Stripe (beginning top of head, ending at bottom of jaw), white fur on paws',
#         'skin issues on rear', 'Left ear is tipped.',
#         'White strip of fur on her snout, and the back of her head.',
#         'White fur on its paws',
#         'White strip of fur going down her chest.',
#         'This animal has an open gash on the top of its head.',
#         'This dog has a minor cut to its right ear and the top, and also irritation to the corner area of both eyes near the bridge of his nose.',
#         'only has one back leg. JS', 'Damaged Right Ear', 'L ear tipped',
#         'old rodent ulcer scar on upper lip.',
#         'WHITE SPOT ON BACK OF NECK',
#         'White down face and white stockings', 'Tan on tail', 'BLUE EYES',
#         'White around neck', 'LEFT EAR TIP ', 'stripe down nose',
#         'White Fur on her chest area',
#         'right ear tipped, left ear has a notch out of it', 'Matted',
#         'This animal has puss bumps on/around its anal area, and hair loss on its bottom back (close to buttocks) as well as her tail.',
#         'Right Ear Tipped', 'Left Ear Tipped',
#         'Eyes are swollen from attack.', 'Skin condition along lower back',
#         'Eyes cloudy and red/ retained dec. teeth gingivitis',
#         'ear tipped', 'Ear tip', 'ringworm tail', 'wound on tail',
#         'minor skin issues towards the butt and legs', 'one white paw',
#         'no white on chest', 'Right ear notch.', 'possibly deaf/blind',
#         'wound on right collar bone ', 'Mustache', 'missing right eye',
#         'white lip, some white on chest, right toe has white on it.',
#         'White spot on chin', 'Wirey hair, white toes, and mouth',
#         'white belly and chin', 'white spot on chin',
#         'small white patch on chest', 'Injured rear right leg ',
#         'white  toe', 'white on top of front paws',
#         'White &quot;T&quot; on chest',
#         'one of the dog paw seemed hurt. FW', 'polydactyl',
#         'white toes/white chest', 'Bottom jaw looks broken. FW ',
#         'Kitten of A42383143 currently in CHH', 'Poss. HBC',
#         'Microchip #982126053187295', 'NO CHIP WHEN SCANNED',
#         'Dog was found near general collins ', 'AVID 093348070',
#         'male kitten that has more white on face ',
#         'watery stool, bloody watery stool dark red gums ',
#         'Brown on tail. ', 'Grey on ears and tail',
#         'One ear permanently folds down', 'dry red skin',
#         'NO CHIP FOUND WHEN SCANNED', 'POSSIBLE RINGWORM',
#         'Bullseye pattern', 'scars on head', 'MEDICAL RECORDS STAPLED',
#         'Black on the ears. ',
#         'right back paw appears to have some skin issues.', 'White toes',
#         'Black Paws', 'White front legs', 'White down Muzzle', 'runt',
#         'White socks', 'white socks', 'white chest white socks',
#         'studded collar. No chip found when scanned',
#         'White Socks, and white patch in face. ',
#         'this kitten has lighter face ',
#         'completely matted MICROCHIP#4B1A2C103A', 'POSS. BLIND',
#         '6 in litter 5 blk/wht 1 grey/wht', 'brown leather buckle collar',
#         'old injury to front right leg', 'POSSIBLE COCCIDIA',
#         'Black spot on left eye', 'Black spot on nose',
#         'One light blue eye, one brown eye. FW ', 'white spot on his back',
#         'brown face with white line going down it ',
#         'Face is a little swollen. FW',
#         'tri color, blk collar with wht bones ',
#         'Black on top, white belly and paws', 'WHt Shep brown nose',
#         'Only non tortie in litter',
#         'brown collar no tags and no chip found',
#         'missing half dollar size patch of fur on shoulder',
#         'injuries to mouth and legs', 'injuries to neck',
#         'no chip found when scanned', 'tattoo',
#         ' Animal has two puncture wounds on his right side.',
#         'scar on caudal dorsal', 'Skin condition missing front right K-9',
#         'green tattoo', 'skinned injured nose', 'one kinked ear', 'MANGE',
#         'one ear up', 'Black tongue', 'patch on left shoulder blade',
#         'Right ear erect ',
#         'two brown spots around eyes, tiny brown spots on body.',
#         'Microchip # 982000363566054', 'black mouth', 'White on shoulders',
#         'this kitten has less orange markings on the body ',
#         'this kitten has more orange on body ',
#         'army camo tag collar with skulls',
#         'siblings A42387422 A42387422, shorter fur then tabby brother and most friendly of litter',
#         'sibling A42387353 A42387422', 'siblings A42387353 A42387415',
#         'Missing rear right leg. right ear is tipped.',
#         'Please change name to Dave if male', 'Underbite',
#         'Black spot on rear ', 'heterochromia, deaf',
#         'underbite and growth on top lip', 'SEE FOOD MEMO AND VET RECORDS',
#         'injury on rear front left paw',
#         'pink dress may have been put on by finder',
#         'males have brindle paws, most outgoing, semi erect ears',
#         'only solid in litter', 'brindle female, one white paw',
#         'brindle female, large nose stripe',
#         'One brown spot on top of her head.',
#         'Look like a simi-old (possible healing) injury on the cat left side. ',
#         'Dog has skin condition patch on right side',
#         'No Chip found when scanned ', 'possibly pregnant',
#         'Chained in force standing postion no aceess to F/W/S No CHip'],
#        dtype=object),
#  374,
#  count                            374
#  unique                           308
#  top       NO CHIP FOUND WHEN SCANNED
#  freq                               8
#  Name: Distinguishing Markings, dtype: object)

# %%
#gender will definitely be used but lets see if any are not M or F
data_df['Gender'].describe(), data_df['Gender'].unique()
# Out:
# (count     12372
#  unique        3
#  top           M
#  freq       6198
#  Name: Gender, dtype: object,
#  array(['M', 'F', 'U'], dtype=object))

# %%
clean_data['Gender'] = data_df['Gender']

# %%
#all animals should be altered at the outcome
data_df['Altered'].describe(), data_df['Altered'].unique()
# Out:
# (count     12372
#  unique        2
#  top         Yes
#  freq      12326
#  Name: Altered, dtype: object,
#  array(['Yes', 'No'], dtype=object))

# %%
#how many are no
data_df[data_df['Altered'] == 'No']
#only 46 - not enough to perform meaningful evaluation on this factor.  i'm more interested in whether they were altered at
#intake which I will have to get separately.
# Out:
#        Animal #         ARN                 Animal Name Animal Type Species  \
# 558   A30483910     LA51671                         Jax         Dog     Dog
# 739   A31638187    LA57950A                    Stallone         Cat     Cat
# 1008  A33254069    LA58092A        Ebony( renamed Onyx)         Dog     Dog
# 1427  A25299664    LA54355A                        Kiki         Dog     Dog
# 1843  A29984391     LA30263                         Zoe         Dog     Dog
# 1875  A30257815    LA57301A                  Jamie Bond         Cat     Cat
# 1926  A30504573         NaN                      Travis         Dog     Dog
# 2336  A33282823    LA58189A       Paint( re named Kora)         Cat     Cat
# 2377  A33783596    LA58624A                      Maggie         Dog     Dog
# 2888  A29578826    la55670a                      Parker         Cat     Cat
# 3088  A30415713    LA57255A     Abby( re named Jezebel)         Cat     Cat
# 3954  A30239542     LA51934                   Jane Bond         Cat     Cat
# 3993  A30337809    LA57205A                    Francine         Cat     Cat
# 4202  A33059230     LA59255                         NaN         Cat     Cat
# 4213  A33067949     LA59308                         NaN         Cat     Cat
# 4250  A33342669    LA58432A    Snickers (renamed Chewy)         Dog     Dog
# 4392  A34069885     la62371     Ernie( re named Bradyn)         Dog     Dog
# 29    A31638187    LA57950A                    Stallone         Cat     Cat
# 206   A35126643  LA 61447 A                      Mickey         Cat     Cat
# 207   A35126762         NaN                         NaN         Cat     Cat
# 434   A36253851    LA62450A                     Camilla         Cat     Cat
# 524   A36801007    la62176a                      Harley         Dog     Dog
# 700   A37535798    LA60048A          Sky(Renamed Rosie)         Dog     Dog
# 959   A38557920    LA61130A      Precious(Renamed Roxy)         Dog     Dog
# 985   A38755624     LA58006                        Fitz         Dog     Dog
# 1174  A39453226     la63110       Pierre(Renamed Ollie)         Dog     Dog
# 1575  A13775490     LA60558                       Dusty         Dog     Dog
# 2317  A37903088      972526      Kelsea (Renamed Gypsy)         Cat     Cat
# 2397  A38149967    LA60760A                      Ralphy         Dog     Dog
# 3019  A35842521    LA62113A                        Coco         Dog     Dog
# 3258  A37237231    LA60188A        Anna(Re-named Annie)         Dog     Dog
# 3328  A37420684     LA61153     Fiona(Re-named Olympia)         Dog     Dog
# 3342  A37430435    LA60135A        Pixie(Re-named Izzy)         Cat     Cat
# 3878  A39626191     LA63326                     Squishy         Cat     Cat
# 3897  A39767954    LA 58918                      Gracie         Dog     Dog
# 4266  A35316732    LA61508A                       Logan         Dog     Dog
# 4293  A35357819    la59744a       Lucy(re named Stella)         Dog     Dog
# 4650  A37090954    LA62931A                        Fatz         Dog     Dog
# 4800  A37757778    LA60417A        Chloe(Re-named Cali)         Dog     Dog
# 4838  A37801787     LA62689                        Coco         Dog     Dog
# 5071  A39322170     LA58527                    Magnolia         Cat     Cat
# 708   A43500075         NaN                      Kahlua         Dog     Dog
# 871   A40793475     LA60153                       Telly         Cat     Cat
# 911   A41149909     LA66172                        Oreo         Dog     Dog
# 1791  A42796565     LA61677  Beatrice(Re-named Beatrix)         Cat     Cat
# 2172  A41655201     LA66500                       Hazel         Dog     Dog
#
#                          Primary Breed        Secondary Breed  \
# 558                   Alaskan Malamute                    NaN
# 739                 Domestic Shorthair                    Mix
# 1008                 Poodle, Miniature                    Mix
# 1427                           Maltese                    Mix
# 1843                      Bichon Frise                    Mix
# 1875                Domestic Shorthair                    Mix
# 1926               Retriever, Labrador                    NaN
# 2336                Domestic Shorthair                    Mix
# 2377         Spaniel, English Springer                    NaN
# 2888                Domestic Shorthair                    Mix
# 3088              Domestic Medium Hair                    Mix
# 3954                Domestic Shorthair                    Mix
# 3993                Domestic Shorthair                    Mix
# 4202                Domestic Shorthair                    Mix
# 4213                Domestic Shorthair                    Mix
# 4250                          Papillon                    Mix
# 4392                           Terrier                    Mix
# 29                  Domestic Shorthair                    Mix
# 206                 Domestic Shorthair                    Mix
# 207                 Domestic Shorthair                    Mix
# 434                            Siamese                    Mix
# 524   Dachshund, Miniature Long Haired                    Mix
# 700                  Terrier, Pit Bull                    Mix
# 959                 Terrier, Yorkshire                    Mix
# 985                  Shetland Sheepdog                    Mix
# 1174               Schnauzer, Standard                    Mix
# 1575                 Retriever, Golden                    Mix
# 2317                Domestic Shorthair                    NaN
# 2397                           Terrier                    Mix
# 3019             Chihuahua, Short Coat                    Mix
# 3258               Retriever, Labrador                    Mix
# 3328    Australian Shepherd, Miniature                    Mix
# 3342                Domestic Shorthair                    Mix
# 3878                Domestic Shorthair                    Mix
# 3897               Retriever, Labrador                    Mix
# 4266                   German Shepherd                    Mix
# 4293             Chihuahua, Short Coat                    Mix
# 4650                               Pug  Chihuahua, Short Coat
# 4800               Retriever, Labrador                    Mix
# 4838                          Shih Tzu                Maltese
# 5071                Domestic Shorthair                    Mix
# 708                          Retriever                    Mix
# 871                 Domestic Shorthair                    Mix
# 911                           Shih Tzu                    Mix
# 1791                Domestic Shorthair                    Mix
# 2172               Retriever, Labrador                    Mix
#
#             Distinguishing Markings Gender Altered  ... Outcome Agency Name  \
# 558                             NaN      M      No  ...                 NaN
# 739                             NaN      M      No  ...                 NaN
# 1008                            NaN      F      No  ...                 NaN
# 1427                            NaN      M      No  ...                 NaN
# 1843                            NaN      F      No  ...                 NaN
# 1875                            NaN      F      No  ...                 NaN
# 1926                            NaN      M      No  ...                 NaN
# 2336                            NaN      F      No  ...                 NaN
# 2377                            NaN      F      No  ...                 NaN
# 2888                            NaN      F      No  ...                 NaN
# 3088                            NaN      F      No  ...                 NaN
# 3954                            NaN      F      No  ...                 NaN
# 3993                            NaN      F      No  ...                 NaN
# 4202                            NaN      F      No  ...                 NaN
# 4213                            NaN      F      No  ...                 NaN
# 4250                            NaN      M      No  ...                 NaN
# 4392                            NaN      M      No  ...                 NaN
# 29                              NaN      M      No  ...                 NaN
# 206                             NaN      M      No  ...                 NaN
# 207                             NaN      F      No  ...                 NaN
# 434                             NaN      F      No  ...                 NaN
# 524                             NaN      F      No  ...                 NaN
# 700                             NaN      F      No  ...                 NaN
# 959                             NaN      F      No  ...                 NaN
# 985                             NaN      M      No  ...                 NaN
# 1174                            NaN      M      No  ...                 NaN
# 1575                            NaN      M      No  ...                 NaN
# 2317                            NaN      F      No  ...                 NaN
# 2397                            NaN      M      No  ...                 NaN
# 3019                            NaN      F      No  ...                 NaN
# 3258                            NaN      F      No  ...                 NaN
# 3328                            NaN      F      No  ...                 NaN
# 3342                            NaN      F      No  ...                 NaN
# 3878  Eyes are swollen from attack.      F      No  ...                 NaN
# 3897                            NaN      F      No  ...                 NaN
# 4266                            NaN      M      No  ...                 NaN
# 4293                            NaN      F      No  ...                 NaN
# 4650                            NaN      F      No  ...                 NaN
# 4800                            NaN      F      No  ...                 NaN
# 4838                            NaN      F      No  ...                 NaN
# 5071                            NaN      F      No  ...                 NaN
# 708                             NaN      F      No  ...                 NaN
# 871                             NaN      F      No  ...                 NaN
# 911                             NaN      M      No  ...                 NaN
# 1791                            NaN      F      No  ...                 NaN
# 2172                            NaN      F      No  ...                 NaN
#
#      Agency Street Address Agency Unit Number  Agency City Agency Province  \
# 558                    NaN                NaN          NaN             NaN
# 739                    NaN                NaN          NaN             NaN
# 1008                   NaN                NaN          NaN             NaN
# 1427                   NaN                NaN          NaN             NaN
# 1843                   NaN                NaN          NaN             NaN
# 1875                   NaN                NaN          NaN             NaN
# 1926                   NaN                NaN          NaN             NaN
# 2336                   NaN                NaN          NaN             NaN
# 2377                   NaN                NaN          NaN             NaN
# 2888                   NaN                NaN          NaN             NaN
# 3088                   NaN                NaN          NaN             NaN
# 3954                   NaN                NaN          NaN             NaN
# 3993                   NaN                NaN          NaN             NaN
# 4202                   NaN                NaN          NaN             NaN
# 4213                   NaN                NaN          NaN             NaN
# 4250                   NaN                NaN          NaN             NaN
# 4392                   NaN                NaN          NaN             NaN
# 29                     NaN                NaN          NaN             NaN
# 206                    NaN                NaN          NaN             NaN
# 207                    NaN                NaN          NaN             NaN
# 434                    NaN                NaN          NaN             NaN
# 524                    NaN                NaN          NaN             NaN
# 700                    NaN                NaN          NaN             NaN
# 959                    NaN                NaN          NaN             NaN
# 985                    NaN                NaN          NaN             NaN
# 1174                   NaN                NaN          NaN             NaN
# 1575                   NaN                NaN          NaN             NaN
# 2317                   NaN                NaN          NaN             NaN
# 2397                   NaN                NaN          NaN             NaN
# 3019                   NaN                NaN          NaN             NaN
# 3258                   NaN                NaN          NaN             NaN
# 3328                   NaN                NaN          NaN             NaN
# 3342                   NaN                NaN          NaN             NaN
# 3878                   NaN                NaN          NaN             NaN
# 3897                   NaN                NaN          NaN             NaN
# 4266                   NaN                NaN          NaN             NaN
# 4293                   NaN                NaN          NaN             NaN
# 4650                   NaN                NaN          NaN             NaN
# 4800                   NaN                NaN          NaN             NaN
# 4838                   NaN                NaN          NaN             NaN
# 5071                   NaN                NaN          NaN             NaN
# 708                    NaN                NaN          NaN             NaN
# 871                    NaN                NaN          NaN             NaN
# 911                    NaN                NaN          NaN             NaN
# 1791                   NaN                NaN          NaN             NaN
# 2172                   NaN                NaN          NaN             NaN
#
#      Agency Postal Code Agency Email Agency Home Phone Agency Cell Number RN
# 558                 NaN          NaN               NaN                NaN  1
# 739                 NaN          NaN               NaN                NaN  1
# 1008                NaN          NaN               NaN                NaN  1
# 1427                NaN          NaN               NaN                NaN  1
# 1843                NaN          NaN               NaN                NaN  1
# 1875                NaN          NaN               NaN                NaN  1
# 1926                NaN          NaN               NaN                NaN  1
# 2336                NaN          NaN               NaN                NaN  1
# 2377                NaN          NaN               NaN                NaN  1
# 2888                NaN          NaN               NaN                NaN  1
# 3088                NaN          NaN               NaN                NaN  1
# 3954                NaN          NaN               NaN                NaN  1
# 3993                NaN          NaN               NaN                NaN  1
# 4202                NaN          NaN               NaN                NaN  1
# 4213                NaN          NaN               NaN                NaN  1
# 4250                NaN          NaN               NaN                NaN  1
# 4392                NaN          NaN               NaN                NaN  1
# 29                  NaN          NaN               NaN                NaN  1
# 206                 NaN          NaN               NaN                NaN  1
# 207                 NaN          NaN               NaN                NaN  1
# 434                 NaN          NaN               NaN                NaN  1
# 524                 NaN          NaN               NaN                NaN  1
# 700                 NaN          NaN               NaN                NaN  1
# 959                 NaN          NaN               NaN                NaN  1
# 985                 NaN          NaN               NaN                NaN  1
# 1174                NaN          NaN               NaN                NaN  1
# 1575                NaN          NaN               NaN                NaN  1
# 2317                NaN          NaN               NaN                NaN  1
# 2397                NaN          NaN               NaN                NaN  1
# 3019                NaN          NaN               NaN                NaN  1
# 3258                NaN          NaN               NaN                NaN  1
# 3328                NaN          NaN               NaN                NaN  1
# 3342                NaN          NaN               NaN                NaN  1
# 3878                NaN          NaN               NaN                NaN  1
# 3897                NaN          NaN               NaN                NaN  1
# 4266                NaN          NaN               NaN                NaN  1
# 4293                NaN          NaN               NaN                NaN  1
# 4650                NaN          NaN               NaN                NaN  1
# 4800                NaN          NaN               NaN                NaN  1
# 4838                NaN          NaN               NaN                NaN  1
# 5071                NaN          NaN               NaN                NaN  1
# 708                 NaN          NaN               NaN                NaN  1
# 871                 NaN          NaN               NaN                NaN  1
# 911                 NaN          NaN               NaN                NaN  1
# 1791                NaN          NaN               NaN                NaN  1
# 2172                NaN          NaN               NaN                NaN  1
#
# [46 rows x 87 columns]

# %%
data_df['Danger'].unique(), data_df['Danger'].notna().sum(), data_df['Danger'].describe()
# Out:
# (array(['No', 'Yes'], dtype=object),
#  12372,
#  count     12372
#  unique        2
#  top          No
#  freq      12323
#  Name: Danger, dtype: object)

# %%
#how many yes
data_df[data_df['Danger'] == 'Yes']
# only 50 - not enough to be a meaningful factor in analysis - excluding this and danger reason
# Out:
#        Animal #       ARN                    Animal Name Animal Type Species  \
# 65    A24926339  LA54510A                          Sarge         Dog     Dog
# 1058  A33550897  LA58138A          Diego (renamed Chico)         Dog     Dog
# 1116  A33752620  LA58383A                          Addie         Dog     Dog
# 1356  A24781891   LA56839        Maddie(Re-named Villet)         Dog     Dog
# 2485  A34189493   LA61634            Emory(Renamed Rudy)         Cat     Cat
# 3369  A31916934  LA57774A          Cindy(Re-named Neige)         Dog     Dog
# 3710  A29284677   LA61403         Krissy( re named Jinx)         Cat     Cat
# 3863  A30051691       NaN                       Knockout         Dog     Dog
# 3917  A30182759   LA52131                        Cruiser         Dog     Dog
# 3926  A30191215  LA57175A                          Henry         Cat     Cat
# 4242  A33331604   LA62661          Noah(re named Pierre)         Dog     Dog
# 4356  A34015215  LA61850a                          Lyric         Dog     Dog
# 4359  A34018863  LA58852A                            Kya         Dog     Dog
# 4597  A25100387   LA57136                          Penny         Dog     Dog
# 56    A33579564   LA59289              Tullo - Underdog!         Dog     Dog
# 197   A35122897    LA6946                            Ace         Dog     Dog
# 303   A35668707  la61977a           Heidi(Re-named Baby)         Dog     Dog
# 436   A36254379  LA62456A                        Pumpkin         Cat     Cat
# 437   A36254379  LA62456A                        Pumpkin         Cat     Cat
# 511   A36646929  LA62573A   Tabeana (Bean)  (was Merida)         Dog     Dog
# 549   A36827602   LA62829                        Charlie         Dog     Dog
# 691   A37522572   LA60245                          Bobby         Dog     Dog
# 905   A38346111   LA64031          Gorda(Re-named Edith)         Dog     Dog
# 978   A38745729   LA64252                          Rusty         Dog     Dog
# 996   A38764287  LA 58011                          Kelly         Dog     Dog
# 1642  A34267168   LA58168                           Papa         Dog     Dog
# 2191  A37376723   LA61191       Lorelai (renamed Willow)         Dog     Dog
# 2244  A37584857       NaN                            Max         Dog     Dog
# 2614  A39226080   LA58488     Dino Diamond(Renamed Roux)         Dog     Dog
# 2748  A34717295   la61994                           Nate         Cat     Cat
# 3107  A36461927  la62641a         Ebbie(Re-named Webbie)         Cat     Cat
# 3271  A37251079   LA61418                         Hikari         Cat     Cat
# 3452  A37960548  LA60540A                          Helen         Dog     Dog
# 3455  A37969717   LA62894                           Baja         Dog     Dog
# 3509  A38192393  LA60834A                         Hobbit         Dog     Dog
# 3545  A38416355       NaN                          Hades         Cat     Cat
# 3564  A38430601   LA62612        Raliegh(Re-named Ralph)         Dog     Dog
# 3713  A38918939   la60498                         Snight         Dog     Dog
# 3716  A38983877   la64478        Chance(Renamed Beaurad)         Dog     Dog
# 3848  A39586733   LA63233                          Teddy         Dog     Dog
# 4151  A34848560  LA59566A                            Sia         Cat     Cat
# 4368  A35636570   LA61043  Bon Jovi(re-named Cam Newton)         Cat     Cat
# 4499  A36198173  LA62053A                          Gezzy         Dog     Dog
# 5340  A30302321   LA61319                         Lassie         Dog     Dog
# 1205  A42707888   LA65163                       Midnight         Cat     Cat
# 1312  A31005427   LA60080                        Diamond         Dog     Dog
# 1362  A38037807  LA60650A                          Jamal         Dog     Dog
# 1377  A40574066   LA65958                          Poppy         Dog     Dog
# 2171  A41655059   LA63620                          Chulo         Dog     Dog
#
#                                        Primary Breed        Secondary Breed  \
# 65                                   German Shepherd                    Mix
# 1058                            Chihuahua, Long Coat                    Mix
# 1116                                        Shih Tzu                    Mix
# 1356                                   Border Collie                    Mix
# 2485                              Domestic Shorthair                    Mix
# 3369                               Poodle, Miniature                    Mix
# 3710                              Domestic Shorthair                    Mix
# 3863                               Terrier, Pit Bull                    Mix
# 3917                                        Shepherd                    Mix
# 3926                              Domestic Shorthair                    Mix
# 4242                                        Shih Tzu                    Mix
# 4356                                      Lhasa Apso                Maltese
# 4359                            Chihuahua, Long Coat                    Mix
# 4597                               Poodle, Miniature                    Mix
# 56      Mixed Breed, Large (over 44 lbs fully grown)                    Mix
# 197                                       Rottweiler                    NaN
# 303                             Chihuahua, Long Coat             Pomeranian
# 436                               Domestic Shorthair                    Mix
# 437                               Domestic Shorthair                    Mix
# 511   Mixed Breed, Medium (up to 44 lbs fully grown)                    Mix
# 549                              Retriever, Labrador                    Mix
# 691                                Poodle, Miniature                Maltese
# 905                              Retriever, Labrador                    Mix
# 978                              Retriever, Labrador                    Mix
# 996                                Terrier, Pit Bull                    Mix
# 1642                               Terrier, Pit Bull                    Mix
# 2191                                         Whippet                    Mix
# 2244                             Retriever, Labrador                    Mix
# 2614                           Chihuahua, Short Coat                    Mix
# 2748                              Domestic Shorthair                    Mix
# 3107                                          Bombay                    Mix
# 3271                              Domestic Shorthair                    Mix
# 3452                           Terrier, Jack Russell  Chihuahua, Short Coat
# 3455                Dachshund, Miniature Long Haired                    Mix
# 3509                           Chihuahua, Short Coat                    Mix
# 3545                              Domestic Shorthair                    Mix
# 3564               Dachshund, Standard Smooth Haired                    Pug
# 3713                                         Terrier                    Mix
# 3716                                         Terrier                    Mix
# 3848                                         Terrier                    Mix
# 4151                                         Siamese                    Mix
# 4368                              Domestic Shorthair                    Mix
# 4499                              Miniature Pinscher                    Mix
# 5340                                         Spaniel                    Mix
# 1205                              Domestic Shorthair                    Mix
# 1312                             Retriever, Labrador                    Mix
# 1362  Mixed Breed, Medium (up to 44 lbs fully grown)                    Mix
# 1377                                 German Shepherd                    Mix
# 2171                                         Terrier                    Mix
#
#      Distinguishing Markings Gender Altered  ... Outcome Agency Name  \
# 65                       NaN      M     Yes  ...                 NaN
# 1058                     NaN      M     Yes  ...                 NaN
# 1116                     NaN      F     Yes  ...                 NaN
# 1356                     NaN      F     Yes  ...                 NaN
# 2485                     NaN      M     Yes  ...                 NaN
# 3369                     NaN      F     Yes  ...                 NaN
# 3710                     NaN      F     Yes  ...                 NaN
# 3863                     NaN      M     Yes  ...                 NaN
# 3917                     NaN      M     Yes  ...                 NaN
# 3926                     NaN      M     Yes  ...                 NaN
# 4242                     NaN      M     Yes  ...                 NaN
# 4356                     NaN      F     Yes  ...                 NaN
# 4359                     NaN      F     Yes  ...                 NaN
# 4597                     NaN      F     Yes  ...                 NaN
# 56                       NaN      M     Yes  ...                 NaN
# 197                      NaN      M     Yes  ...                 NaN
# 303                      NaN      F     Yes  ...                 NaN
# 436                      NaN      F     Yes  ...                 NaN
# 437                      NaN      F     Yes  ...                 NaN
# 511                      NaN      F     Yes  ...                 NaN
# 549                      NaN      F     Yes  ...                 NaN
# 691                      NaN      M     Yes  ...                 NaN
# 905                      NaN      F     Yes  ...                 NaN
# 978                      NaN      F     Yes  ...                 NaN
# 996                      NaN      F     Yes  ...                 NaN
# 1642                     NaN      M     Yes  ...                 NaN
# 2191                     NaN      F     Yes  ...                 NaN
# 2244                     NaN      M     Yes  ...                 NaN
# 2614                     NaN      M     Yes  ...                 NaN
# 2748                     NaN      M     Yes  ...                 NaN
# 3107                     NaN      M     Yes  ...                 NaN
# 3271                     NaN      M     Yes  ...                 NaN
# 3452                     NaN      F     Yes  ...                 NaN
# 3455                     NaN      F     Yes  ...                 NaN
# 3509                     NaN      M     Yes  ...                 NaN
# 3545                     NaN      M     Yes  ...                 NaN
# 3564                     NaN      M     Yes  ...                 NaN
# 3713                     NaN      M     Yes  ...                 NaN
# 3716                     NaN      M     Yes  ...                 NaN
# 3848                     NaN      M     Yes  ...                 NaN
# 4151                     NaN      F     Yes  ...                 NaN
# 4368                     NaN      M     Yes  ...                 NaN
# 4499                     NaN      M     Yes  ...                 NaN
# 5340                     NaN      M     Yes  ...                 NaN
# 1205                     NaN      F     Yes  ...                 NaN
# 1312                     NaN      F     Yes  ...                 NaN
# 1362                     NaN      M     Yes  ...                 NaN
# 1377                     NaN      F     Yes  ...                 NaN
# 2171                     NaN      M     Yes  ...                 NaN
#
#      Agency Street Address Agency Unit Number  Agency City Agency Province  \
# 65                     NaN                NaN          NaN             NaN
# 1058                   NaN                NaN          NaN             NaN
# 1116                   NaN                NaN          NaN             NaN
# 1356                   NaN                NaN          NaN             NaN
# 2485                   NaN                NaN          NaN             NaN
# 3369                   NaN                NaN          NaN             NaN
# 3710                   NaN                NaN          NaN             NaN
# 3863                   NaN                NaN          NaN             NaN
# 3917                   NaN                NaN          NaN             NaN
# 3926                   NaN                NaN          NaN             NaN
# 4242                   NaN                NaN          NaN             NaN
# 4356                   NaN                NaN          NaN             NaN
# 4359                   NaN                NaN          NaN             NaN
# 4597                   NaN                NaN          NaN             NaN
# 56                     NaN                NaN          NaN             NaN
# 197                    NaN                NaN          NaN             NaN
# 303                    NaN                NaN          NaN             NaN
# 436                    NaN                NaN          NaN             NaN
# 437                    NaN                NaN          NaN             NaN
# 511                    NaN                NaN          NaN             NaN
# 549                    NaN                NaN          NaN             NaN
# 691                    NaN                NaN          NaN             NaN
# 905                    NaN                NaN          NaN             NaN
# 978                    NaN                NaN          NaN             NaN
# 996                    NaN                NaN          NaN             NaN
# 1642                   NaN                NaN          NaN             NaN
# 2191                   NaN                NaN          NaN             NaN
# 2244                   NaN                NaN          NaN             NaN
# 2614                   NaN                NaN          NaN             NaN
# 2748                   NaN                NaN          NaN             NaN
# 3107                   NaN                NaN          NaN             NaN
# 3271                   NaN                NaN          NaN             NaN
# 3452                   NaN                NaN          NaN             NaN
# 3455                   NaN                NaN          NaN             NaN
# 3509                   NaN                NaN          NaN             NaN
# 3545                   NaN                NaN          NaN             NaN
# 3564                   NaN                NaN          NaN             NaN
# 3713                   NaN                NaN          NaN             NaN
# 3716                   NaN                NaN          NaN             NaN
# 3848                   NaN                NaN          NaN             NaN
# 4151                   NaN                NaN          NaN             NaN
# 4368                   NaN                NaN          NaN             NaN
# 4499                   NaN                NaN          NaN             NaN
# 5340                   NaN                NaN          NaN             NaN
# 1205                   NaN                NaN          NaN             NaN
# 1312                   NaN                NaN          NaN             NaN
# 1362                   NaN                NaN          NaN             NaN
# 1377                   NaN                NaN          NaN             NaN
# 2171                   NaN                NaN          NaN             NaN
#
#      Agency Postal Code Agency Email Agency Home Phone Agency Cell Number RN
# 65                  NaN          NaN               NaN                NaN  1
# 1058                NaN          NaN               NaN                NaN  1
# 1116                NaN          NaN               NaN                NaN  1
# 1356                NaN          NaN               NaN                NaN  1
# 2485                NaN          NaN               NaN                NaN  1
# 3369                NaN          NaN               NaN                NaN  1
# 3710                NaN          NaN               NaN                NaN  1
# 3863                NaN          NaN               NaN                NaN  1
# 3917                NaN          NaN               NaN                NaN  1
# 3926                NaN          NaN               NaN                NaN  1
# 4242                NaN          NaN               NaN                NaN  1
# 4356                NaN          NaN               NaN                NaN  1
# 4359                NaN          NaN               NaN                NaN  1
# 4597                NaN          NaN               NaN                NaN  1
# 56                  NaN          NaN               NaN                NaN  1
# 197                 NaN          NaN               NaN                NaN  1
# 303                 NaN          NaN               NaN                NaN  1
# 436                 NaN          NaN               NaN                NaN  1
# 437                 NaN          NaN               NaN                NaN  1
# 511                 NaN          NaN               NaN                NaN  1
# 549                 NaN          NaN               NaN                NaN  1
# 691                 NaN          NaN               NaN                NaN  1
# 905                 NaN          NaN               NaN                NaN  1
# 978                 NaN          NaN               NaN                NaN  1
# 996                 NaN          NaN               NaN                NaN  1
# 1642                NaN          NaN               NaN                NaN  1
# 2191                NaN          NaN               NaN                NaN  1
# 2244                NaN          NaN               NaN                NaN  1
# 2614                NaN          NaN               NaN                NaN  1
# 2748                NaN          NaN               NaN                NaN  1
# 3107                NaN          NaN               NaN                NaN  1
# 3271                NaN          NaN               NaN                NaN  1
# 3452                NaN          NaN               NaN                NaN  1
# 3455                NaN          NaN               NaN                NaN  1
# 3509                NaN          NaN               NaN                NaN  1
# 3545                NaN          NaN               NaN                NaN  1
# 3564                NaN          NaN               NaN                NaN  1
# 3713                NaN          NaN               NaN                NaN  1
# 3716                NaN          NaN               NaN                NaN  1
# 3848                NaN          NaN               NaN                NaN  1
# 4151                NaN          NaN               NaN                NaN  1
# 4368                NaN          NaN               NaN                NaN  1
# 4499                NaN          NaN               NaN                NaN  1
# 5340                NaN          NaN               NaN                NaN  1
# 1205                NaN          NaN               NaN                NaN  1
# 1312                NaN          NaN               NaN                NaN  1
# 1362                NaN          NaN               NaN                NaN  1
# 1377                NaN          NaN               NaN                NaN  1
# 2171                NaN          NaN               NaN                NaN  1
#
# [49 rows x 87 columns]

# %%
data_df.columns
# Out:
# Index(['Animal #', 'ARN', 'Animal Name', 'Animal Type', 'Species',
#        'Primary Breed', 'Secondary Breed', 'Distinguishing Markings', 'Gender',
#        'Altered', 'Danger', 'Danger Reason', 'Date Of Birth',
#        'Age in Months Intake', 'Age Group', 'Intake Asilomar Status',
#        'Intake Condition', 'Intake Record Owner', 'Intake Date', 'Intake Type',
#        'Intake Subtype', 'Found Address', 'Found Zip Code', 'Reason',
#        'Intake SiteName', 'Jurisdiction In', 'Agency Name', 'Agency Member',
#        'Agency Member Phone', 'Agency Address', 'Intake Person ID',
#        'Intake Person ID Type', 'Intake Person #', 'Admitter',
#        'Street Address', 'Unit Number', 'City', 'Province', 'Postal Code',
#        'Admitter's Email', 'Admitter's Home Phone', 'Admitter's Cell Phone',
#        'Initial Stage', 'Initial Review Date', 'Age in Months Current',
#        'Microchip Issue Date', 'Microchip Provider', 'Microchip Number',
#        'Pet ID', 'Pet ID Type', 'Status', 'Stage', 'Location', 'Sublocation',
#        'Outcome Asilomar Status', 'Outcome Number', 'Released By',
#        'Date Created', 'Outcome Date', 'Release Date', 'Outcome Type',
#        'Outcome Subtype', 'Outcome SiteName', 'Jurisdiction Out',
#        'Outcome Reason', 'Outcome Person ID', 'Outcome Person ID Type',
#        'Outcome Person #', 'Outcome Person Name', 'Out Street Address',
#        'Out Unit Number', 'Out City', 'Out Province', 'Out Postal Code',
#        'Out Email', 'Out Home Phone', 'Out Cell Phone', 'Outcome Agency Name',
#        'Agency Street Address', 'Agency Unit Number', 'Agency City',
#        'Agency Province', 'Agency Postal Code', 'Agency Email',
#        'Agency Home Phone', 'Agency Cell Number', 'RN'],
#       dtype='object')

# %%
#a few values relate to the age - date of birth, age in months intake, age in months current.  I want age in months at intake
#and age at outcome.  Need to see if age in months current is based off of todays date or outcome date
#viewing a few fields to determine:
data_df[['Date Of Birth', 'Age in Months Intake', 'Intake Date', 'Age in Months Current', 'Outcome Date']].head()
# Out:
#   Date Of Birth  Age in Months Intake         Intake Date  \
# 0     7/26/2003                 144.0  7/30/2015 12:21 PM
# 1     10/6/2002                 152.0   6/16/2015 3:07 PM
# 2     5/13/2007                 108.0  5/31/2016 10:45 AM
# 3     4/16/2008                  82.0  3/12/2015 11:03 AM
# 4    12/12/2006                  98.0   3/6/2015 10:09 AM
#
#    Age in Months Current        Outcome Date
# 0                  203.0 2015-08-10 10:50:00
# 1                  213.0 2015-06-30 14:22:00
# 2                  158.0 2016-07-25 13:13:00
# 3                  147.0 2015-06-02 15:41:00
# 4                  163.0 2015-03-17 12:24:00

# %%
#age in months current is definitely based on current date.  I'm going to include the date of birth in case i want to calculate
#any more dates, intake date, age in Months Intake, and calculate the age at outcome
clean_data['DOB'] = pd.to_datetime(data_df['Date Of Birth'])
clean_data['IntakeDate'] = pd.to_datetime(data_df['Intake Date'])
clean_data['OutcomeDate'] = pd.to_datetime(data_df['Outcome Date'])
clean_data['IntakeAgeMonths'] = data_df['Age in Months Intake']
clean_data['OutcomeAgeMonths'] = (clean_data['OutcomeDate'] - clean_data['DOB']) / np.timedelta64(1, 'M')

# %%
clean_data.head()
# Out:
#     AnimalID Species          PrimaryBreed      SecondaryBreed Gender  \
# 0  A10338615     Dog             Chow Chow                 Mix      M
# 1  A10345450     Dog     Poodle, Miniature                 Mix      M
# 2  A10357120     Cat    Domestic Shorthair  Domestic Shorthair      F
# 3  A10363334     Dog     Poodle, Miniature                 Mix      M
# 4  A10363778     Cat  Domestic Medium Hair  Domestic Shorthair      F
#
#          DOB          IntakeDate         OutcomeDate  IntakeAgeMonths  \
# 0 2003-07-26 2015-07-30 12:21:00 2015-08-10 10:50:00            144.0
# 1 2002-10-06 2015-06-16 15:07:00 2015-06-30 14:22:00            152.0
# 2 2007-05-13 2016-05-31 10:45:00 2016-07-25 13:13:00            108.0
# 3 2008-04-16 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0
# 4 2006-12-12 2015-03-06 10:09:00 2015-03-17 12:24:00             98.0
#
#    OutcomeAgeMonths
# 0        144.510611
# 1        152.794878
# 2        110.443358
# 3         85.542733
# 4         99.140160

# %%
data_df.columns
# Out:
# Index(['Animal #', 'ARN', 'Animal Name', 'Animal Type', 'Species',
#        'Primary Breed', 'Secondary Breed', 'Distinguishing Markings', 'Gender',
#        'Altered', 'Danger', 'Danger Reason', 'Date Of Birth',
#        'Age in Months Intake', 'Age Group', 'Intake Asilomar Status',
#        'Intake Condition', 'Intake Record Owner', 'Intake Date', 'Intake Type',
#        'Intake Subtype', 'Found Address', 'Found Zip Code', 'Reason',
#        'Intake SiteName', 'Jurisdiction In', 'Agency Name', 'Agency Member',
#        'Agency Member Phone', 'Agency Address', 'Intake Person ID',
#        'Intake Person ID Type', 'Intake Person #', 'Admitter',
#        'Street Address', 'Unit Number', 'City', 'Province', 'Postal Code',
#        'Admitter's Email', 'Admitter's Home Phone', 'Admitter's Cell Phone',
#        'Initial Stage', 'Initial Review Date', 'Age in Months Current',
#        'Microchip Issue Date', 'Microchip Provider', 'Microchip Number',
#        'Pet ID', 'Pet ID Type', 'Status', 'Stage', 'Location', 'Sublocation',
#        'Outcome Asilomar Status', 'Outcome Number', 'Released By',
#        'Date Created', 'Outcome Date', 'Release Date', 'Outcome Type',
#        'Outcome Subtype', 'Outcome SiteName', 'Jurisdiction Out',
#        'Outcome Reason', 'Outcome Person ID', 'Outcome Person ID Type',
#        'Outcome Person #', 'Outcome Person Name', 'Out Street Address',
#        'Out Unit Number', 'Out City', 'Out Province', 'Out Postal Code',
#        'Out Email', 'Out Home Phone', 'Out Cell Phone', 'Outcome Agency Name',
#        'Agency Street Address', 'Agency Unit Number', 'Agency City',
#        'Agency Province', 'Agency Postal Code', 'Agency Email',
#        'Agency Home Phone', 'Agency Cell Number', 'RN'],
#       dtype='object')

# %%
#explore Age Group
data_df['Age Group'].unique(), data_df['Age Group'].notna().sum(), data_df['Age Group'].describe()
# Out:
# (array(['Adult Dog', 'Adult Cat', 'Kitten (6 months or less)',
#         'Puppy (6 months or less)', nan, 'Adult Other', 'Unknown age',
#         'Young Other'], dtype=object),
#  12362,
#  count         12362
#  unique            7
#  top       Adult Dog
#  freq           5423
#  Name: Age Group, dtype: object)

# %%
#explore asilormar status at intake
data_df['Intake Asilomar Status'].unique(), data_df['Intake Asilomar Status'].notna().sum(), data_df['Intake Asilomar Status'].describe()
# Out:
# (array(['Treatable-Manageable', 'Treatable-Rehabilitatable', 'Healthy',
#         'Unhealthy/Untreatable', nan, 'Unassigned'], dtype=object),
#  12354,
#  count       12354
#  unique          5
#  top       Healthy
#  freq         7948
#  Name: Intake Asilomar Status, dtype: object)

# %%
#explore condition at intake
data_df['Intake Condition'].unique(), data_df['Intake Condition'].notna().sum(), data_df['Intake Condition'].describe()
# Out:
# (array(['Geriatic', 'Appears Normal', 'Skin Condition',
#         'Heartworm Positive', 'Normal', 'Unknown', 'Injured/wounds',
#         'Emaciated/Thin', 'Sick & Injured', 'Feral', 'Sick', 'Healthy',
#         nan], dtype=object),
#  12371,
#  count              12371
#  unique                12
#  top       Appears Normal
#  freq                7244
#  Name: Intake Condition, dtype: object)

# %%
#evaluate intake categorical info
data_df['Intake Type'].unique(), data_df['Intake Type'].notna().sum(), data_df['Intake Type'].describe()
# Out:
# (array(['Owner/Guardian Surrender', 'Seized / Custody', 'Stray', 'Return',
#         'Transfer In'], dtype=object),
#  12372,
#  count     12372
#  unique        5
#  top       Stray
#  freq       5917
#  Name: Intake Type, dtype: object)

# %%
data_df['Intake Subtype'].unique(), data_df['Intake Subtype'].notna().sum(), data_df['Intake Subtype'].describe()
# Out:
# (array(['Surrendered', 'Stray Confined', 'Stray Roaming',
#         'Stray Bite Case', 'Public Drop Off', 'Stray Abandoned',
#         'Owner Surrender-Other', 'Stray Possible Owner(ID TAG)',
#         'After Hour Public Drop Off', 'TNR Mitigation',
#         'Returned Adoption', 'Coalition Partner Outside',
#         'Coalition Partner Inside', 'Stray Injured',
#         'Return Adopt(within 30 Days)', 'Owned Seized', 'Bitecase',
#         'Abandoned', 'Stray Cruelty', 'Born in Care',
#         'Owner Surrender - Owner moving', "Owner Surrender-Doesn't Want",
#         'Owner Surrender- Sick Owner', 'Aggression', 'Bite Case',
#         'Owned Abandoned', 'Emergency Response', 'Stray', 'Owned Cruelty',
#         'Cruelty', 'Owner Surrender Court Ordered', 'Owned Bite Case',
#         'Return Barn Cat', 'Euthanasia Request',
#         'Owned Inadequate Housing', 'Owner Surrender Bitecase',
#         'Destruction of Property'], dtype=object),
#  12372,
#  count               12372
#  unique                 37
#  top       Public Drop Off
#  freq                 4712
#  Name: Intake Subtype, dtype: object)

# %%
#add these values to the clean dataset
clean_data['AgeGroup'] = data_df['Age Group']
clean_data['IntakeAsilomar'] = data_df['Intake Asilomar Status']
clean_data['IntakeCondition'] = data_df['Intake Condition']
clean_data['IntakeType'] = data_df['Intake Type']
clean_data['IntakeSubType'] = data_df['Intake Subtype']

# %%
#explore location found
data_df['Found Address'].unique(), data_df['Found Address'].notna().sum(), data_df['Found Address'].describe()
#this data can be very random because of the 6249 unique values, also the top entry is the address of the main shelter
# Out:
# (array([nan, '5300 Blk of Franklin Ave.', '4638 Washington', ...,
#         '5700 Read Boulevard', '4314 Shell Road', '3810 Red Cypress Dr'],
#        dtype=object),
#  8829,
#  count                     8829
#  unique                    6249
#  top       1700 Mardi Gras Blvd
#  freq                        76
#  Name: Found Address, dtype: object)

# %%
data_df['Found Zip Code'].unique(), data_df['Found Zip Code'].notna().sum(), data_df['Found Zip Code'].describe()
#this is numerical value, i want to look at jurisdiction too to see if it is the same as this one
# Out:
# (array([70131., 70114., 70122., 70125., 70118., 70115., 70117., 70126.,
#         70121., 70448., 70065., 70123., 70072., 70130., 70112., 70128.,
#         70053., 70113., 70124., 70119., 70001., 70127., 70062., 70058.,
#         70129., 70068., 70471., 70037., 70005., 70361., 70116., 70002.,
#         70070., 70056., 70363., 70094., 70461., 70006., 39466., 71111.,
#         23510., 70043., 70582., 39769., 70458., 39501., 70003., 39120.,
#         70148., 70403., 70041., 70092., 70460., 39530., 91040., 39638.,
#         70359., 70052., 70814., 34747., 70807., 70014., 70075., 70301.,
#         13601., 70087., 70454., 70433., 70754., 70032., 70420., 75038.,
#         70031., 70809., 70085., 70785., 70769., 70548., 70067., 70615.,
#         70172., 70806., 36509., 70427., 70344., 70789., 70047., 70036.,
#         71301., 70836., 70051., 71203., 70339., 70360., 70079., 70529.,
#         77584., 70445., 70808., 71360., 70401., 70364., 70816., 70586.,
#         10128., 39425., 33912., 29710., 30240., 71458., 30318., 70446.,
#         39564., 32401., 70090., 39170., 70503., 75951., 70447., 70039.,
#         70134., 70820., 78257., 39522., 80439.,    nan, 70706., 40466.,
#         70570., 70162., 20879., 70438., 84121., 70711.,  4106., 70084.,
#         70802., 31401., 80123., 89131., 70019., 70392., 70452., 70083.,
#         39667., 77551., 70437., 71037., 77067., 70394., 27527., 71459.,
#         70380., 28532., 70358., 70817., 70040., 70520., 39402., 90046.,
#         40214., 38654., 76063., 33309., 70012., 70535., 70007., 39531.,
#         70810., 70106., 33619., 90042., 71463., 70762., 70435., 70778.,
#         70546., 70726., 70748., 21117., 91766., 78130., 70340., 70153.,
#         70737., 36608.,  8055., 71333., 70549., 70406., 39047., 94080.,
#         70763., 61401., 44408., 32207., 70054.]),
#  12366,
#  count    12366.000000
#  mean     69785.345221
#  std       4020.473392
#  min       4106.000000
#  25%      70114.000000
#  50%      70119.000000
#  75%      70127.000000
#  max      94080.000000
#  Name: Found Zip Code, dtype: float64)

# %%
data_df['Jurisdiction In'].unique(), data_df['Jurisdiction In'].notna().sum(), data_df['Jurisdiction In'].describe()
# Out:
# (array(['70131', '70114', '70122', '70125', '70118', '70115', '70117',
#         '70126', '70121', '70448', '70065', '70123', '70072', '70130',
#         '70112', '70128', '70053', '70113', '70124', '70005', '70001',
#         '70127', '70119', '70062', '70058', '70129', nan, '70068', '70471',
#         '70037', '70361', '70116', '70002', '70070', '70056', '70363',
#         '70094', '70461', '70006', '71111', '23510', '70043', '70582',
#         'MS', '70458', '39501', '70003', '39120', '70148', '70403',
#         '70041', '70092', '70460', '70359', 'Unknown/Other', '70052',
#         '70814', '70807', '70075', '70301', 'New York', '70087', '70454',
#         '70433', '70754', '70032', '70420', 'TX', '70031', '70809',
#         '70085', '70785', '70769', '70548', '70615', '70806', '70067',
#         'Alabama', '70427', '70344', '70789', '70047', '70036', '71301',
#         '70051', '71203', '70339', '70360', '70079', '70529', '70445',
#         '70808', '70401', '70364', '70816', '39426', '36608', '30116',
#         '29414', '71458', '30318', '70446', '70090', '70503', '75218',
#         '70447', '70170', '70039', '70820', '70706', '70570', '70438',
#         '50624', '70711', '71220', '39406', 'Washington, DC', '70084',
#         '70802', '31548', '80214', '70578', '70392', '70452', '70083',
#         '39667', '70437', '71037', '70394', '70380', '70214', '70358',
#         '70817', '70040', '70520', '40214', '38701', '70535', '70810',
#         'FL', '70762', '70435', '70778', '70560', '70726', '70748',
#         '71943', '70737', 'New Jersey', '70549', '71449', '70763'],
#        dtype=object),
#  12275,
#  count     12275
#  unique      151
#  top       70114
#  freq       1738
#  Name: Jurisdiction In, dtype: object)

# %%
#i like the found zip code better because it is all numeric.  I'm going to convert it to a string value and add it to the dataset
clean_data['FoundZip'] = data_df['Found Zip Code'].apply(str)

# %%
clean_data.head()
# Out:
#     AnimalID Species          PrimaryBreed      SecondaryBreed Gender  \
# 0  A10338615     Dog             Chow Chow                 Mix      M
# 1  A10345450     Dog     Poodle, Miniature                 Mix      M
# 2  A10357120     Cat    Domestic Shorthair  Domestic Shorthair      F
# 3  A10363334     Dog     Poodle, Miniature                 Mix      M
# 4  A10363778     Cat  Domestic Medium Hair  Domestic Shorthair      F
#
#          DOB          IntakeDate         OutcomeDate  IntakeAgeMonths  \
# 0 2003-07-26 2015-07-30 12:21:00 2015-08-10 10:50:00            144.0
# 1 2002-10-06 2015-06-16 15:07:00 2015-06-30 14:22:00            152.0
# 2 2007-05-13 2016-05-31 10:45:00 2016-07-25 13:13:00            108.0
# 3 2008-04-16 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0
# 4 2006-12-12 2015-03-06 10:09:00 2015-03-17 12:24:00             98.0
#
#    OutcomeAgeMonths   AgeGroup             IntakeAsilomar IntakeCondition  \
# 0        144.510611  Adult Dog       Treatable-Manageable        Geriatic
# 1        152.794878  Adult Dog  Treatable-Rehabilitatable  Appears Normal
# 2        110.443358  Adult Cat                    Healthy  Appears Normal
# 3         85.542733  Adult Dog       Treatable-Manageable  Appears Normal
# 4         99.140160  Adult Cat       Treatable-Manageable        Geriatic
#
#                  IntakeType   IntakeSubType FoundZip
# 0  Owner/Guardian Surrender     Surrendered  70131.0
# 1  Owner/Guardian Surrender     Surrendered  70114.0
# 2  Owner/Guardian Surrender     Surrendered  70122.0
# 3          Seized / Custody  Stray Confined  70122.0
# 4  Owner/Guardian Surrender     Surrendered  70131.0

# %%
data_df['Reason'].unique(), data_df['Reason'].notna().sum(),data_df['Reason'].describe()
#there are only 3000 records that have an intake reason entered.  This could be helpful though if looking only at owner
#surrenders.  Taking it to the clean data
# Out:
# (array(['Health of Owner / Family', 'Cannot Afford', 'Moving', nan,
#         'Behavior Issues', 'Dont Want', 'Not Housebroken', 'Other',
#         'Landlord Issues', 'Military Transfer of Owner', 'Unknown',
#         'Health of Animal', 'No Time For Animal',
#         'Pregnancy of Owner / Family', 'Unable to Train', 'Escapes',
#         'Unwanted Litter', 'Adopt Return-Behavior', 'Out of Space',
#         'Aggression to People', 'Adopt Return-Moving',
#         'Allergic to Animal', 'Current Animal is Incompatible',
#         'Adopt Return-Landlord', 'Too Active', 'No Home',
#         'Aggression to Animals', 'Adopt Return-Other', 'Too Noisy',
#         'Stray', 'Death of Owner / Family', 'Adopt Return-Aggression',
#         'Adopt Return-Too Many', 'Adopt Return-Allergy', 'Too Big',
#         'Personal Problems', 'Unrealistic Expectations',
#         'Non-compliance Chap. 18', 'Too Many Animals', 'Adopt Return-Sick',
#         'Destructive', 'Insurance Restrictions', 'Adopt Return-New Baby',
#         'Needs Too Much Attention', 'Abandoned', 'Special Needs',
#         'Not Housebroken / Housesoiling', 'Change in Lifestyle',
#         'Unwanted', 'Intact Permit', 'Not Enough Time',
#         'Destructive Inside', 'Divorce / Separation', 'Bite Case',
#         'Out of Time', "Doesn't Like Other Pets", "Doesn't Like Children",
#         'Not Friendly', 'Potential Adopter', 'Abandoned by Owner',
#         'Animal Injured', 'Euthanasia Request', 'Adopt Return-Cant Afford',
#         'Too Young', 'Too Old', 'Too Much Responsibility',
#         'Chases Animals', 'Unwanted Gift'], dtype=object),
#  3542,
#  count             3542
#  unique              67
#  top       Out of Space
#  freq               843
#  Name: Reason, dtype: object)

# %%
clean_data['IntakeReason'] = data_df['Reason']

# %%
data_df['Intake SiteName'].unique(), data_df['Intake SiteName'].notna().sum()
# Out:
# (array(['LA Shelter'], dtype=object), 12372)

# %%
#all intake was done at the main campus, this intake variable was not needed

# %%
#i'm not concerned with the individuals who turned in the animal or who processed the intake
#however, if the animal came from another animal welfare agency, that may be interesting to see how that affected their
#adoption
data_df['Agency Name'].unique(), data_df['Agency Name'].notna().sum(), data_df['Agency Name'].describe()
# Out:
# (array([nan, 'Louisiana SPCA',
#         'St John The Baptist Parish Animal Shlelter',
#         "My Heart's Desire Pet Adoption Center",
#         'Audubon Center For Rescue of Endagered species ',
#         'Terrebonne Parish Animal Shelter', 'ACRES',
#         'Bossier City Animal Control', 'PETA',
#         'St.Martin Parish Animal Control',
#         'Humane Society of South Mississippi', 'Natchez Pet Adoptions',
#         'Tangipahoa Parish Animal Control',
#         'St Bernard Parish Animal Services', 'St Charles Humane Society',
#         'Companion Animal Alliance', 'Livingston Parish Animal Control',
#         'Plaquemines Animal Welfare Society (PAWS)',
#         'City of Walker Animal Control',
#         'Jefferson Parish Animal Shelter East Bank',
#         'Animal Aid of Vermilion Parish',
#         'Jefferson Parish Animal Shelter',
#         'Calcasieu Parish Animal Services ', 'River Region Animal Rescue',
#         'Used Dogs', 'LA-SPCA Special Issue',
#         'St. Tammany Parish Department of Animal Services', 'ASPCA',
#         'Lee County Domestic Animal Services',
#         'Natchitoches Humane Society', 'St. Tammany Humane Society',
#         'Atlanta humane society', 'Veccs',
#         'Saint Landry Parish Animal Control and Rescue',
#         'Jefferson Parish Animal Shelter West Bank',
#         'Humane Society of United States', 'LA SPCA',
#         'Country Inn Kennels', 'Community Clinic',
#         'Pointe Coupee Animal Shelter ', 'Dixon Correctional Institute',
#         'Animal Rescue New Orleans (ARNO)', 'Pen Pals Rescue'],
#        dtype=object),
#  3795,
#  count               3795
#  unique                42
#  top       Louisiana SPCA
#  freq                2918
#  Name: Agency Name, dtype: object)

# %%
data_df['Agency Member'].unique(), data_df['Agency Member'].notna().sum(), data_df['Agency Member'].describe()
#do not need this info
# Out:
# (array([nan, 'Beth Renfro', 'Samuel Counts', 'Justin Blue', 'Laura Oliver',
#         'Brandi Thibodeaux', 'Travis Causey', 'Sara Dawdy',
#         'Eric Durcinka', 'Linda Allen', 'Amanda Pumilia',
#         'Tracy Lapeyrouse', 'Michelle Hatwood', 'Rachel Brunet',
#         'Noah Harter', 'Brady Cornell', 'Anna Ware', 'Robin Menard',
#         'James Carll', 'Tracy Reis', 'Kathy Fitch', 'Chip Fitz',
#         'Charlotte Luna', 'Lynzee Gray', 'Leonie Agurcia', 'Lily Yap',
#         'Michelle Brignac', 'Desiree Green', 'Chris BeeBee',
#         'Manager Shelter', 'Jefferson Parish', 'Tracy Davenport',
#         'Thaddeus Sunmoni', 'Robin Beaulieu',
#         'Species Survival Center Audubon Nature Institute', 'Anne Godeaux',
#         'Sherri Arias', 'Michelle Abeyta', 'Community Clinic',
#         'Zachary Shupe', 'Rachel Eure', 'Tara Smith', 'Joshua Pechawer',
#         'Kristen Limbert', 'Leah Atkinson', 'Michele Penny',
#         'Juanita Murphy', 'Jacqie Bella', 'Andrea Peacock',
#         'Joshua Critney', 'Gnek Dutton', 'Angel Zuniga', 'Gary Stamp',
#         'Sean Decker', 'Shaun Loose', 'Julia Breaux', 'JPAS Westbank',
#         'Rowdy Shaw', 'Lonnie Senior', 'Rocquel Rainey',
#         'Jessica Lovelady', 'Charlene Millet', 'Mandy Brennan',
#         'Crystal Leviness', 'Mary Morvant', 'Ted Edward Urrutia',
#         'Shane Winans', 'Jessica Hartnett', 'John Smith'], dtype=object),
#  3795,
#  count            3795
#  unique             68
#  top       Justin Blue
#  freq              388
#  Name: Agency Member, dtype: object)

# %%
clean_data['IntakeAgencyAssociation'] = data_df['Agency Name']

# %%
data_df.columns
# Out:
# Index(['Animal #', 'ARN', 'Animal Name', 'Animal Type', 'Species',
#        'Primary Breed', 'Secondary Breed', 'Distinguishing Markings', 'Gender',
#        'Altered', 'Danger', 'Danger Reason', 'Date Of Birth',
#        'Age in Months Intake', 'Age Group', 'Intake Asilomar Status',
#        'Intake Condition', 'Intake Record Owner', 'Intake Date', 'Intake Type',
#        'Intake Subtype', 'Found Address', 'Found Zip Code', 'Reason',
#        'Intake SiteName', 'Jurisdiction In', 'Agency Name', 'Agency Member',
#        'Agency Member Phone', 'Agency Address', 'Intake Person ID',
#        'Intake Person ID Type', 'Intake Person #', 'Admitter',
#        'Street Address', 'Unit Number', 'City', 'Province', 'Postal Code',
#        'Admitter's Email', 'Admitter's Home Phone', 'Admitter's Cell Phone',
#        'Initial Stage', 'Initial Review Date', 'Age in Months Current',
#        'Microchip Issue Date', 'Microchip Provider', 'Microchip Number',
#        'Pet ID', 'Pet ID Type', 'Status', 'Stage', 'Location', 'Sublocation',
#        'Outcome Asilomar Status', 'Outcome Number', 'Released By',
#        'Date Created', 'Outcome Date', 'Release Date', 'Outcome Type',
#        'Outcome Subtype', 'Outcome SiteName', 'Jurisdiction Out',
#        'Outcome Reason', 'Outcome Person ID', 'Outcome Person ID Type',
#        'Outcome Person #', 'Outcome Person Name', 'Out Street Address',
#        'Out Unit Number', 'Out City', 'Out Province', 'Out Postal Code',
#        'Out Email', 'Out Home Phone', 'Out Cell Phone', 'Outcome Agency Name',
#        'Agency Street Address', 'Agency Unit Number', 'Agency City',
#        'Agency Province', 'Agency Postal Code', 'Agency Email',
#        'Agency Home Phone', 'Agency Cell Number', 'RN'],
#       dtype='object')

# %%
#explore initial stage and initial review date
data_df['Initial Stage'].unique(), data_df['Initial Stage'].notna().sum(), data_df['Initial Stage'].describe()
# Out:
# (array(['New Arrival', 'Needs Routing', 'Surgery Completed',
#         'Transport Pending', nan, 'Foster Program', 'Available',
#         'Parvo Quarantine', 'Bite Quarantine', 'Barn Cat Adoptions',
#         'Mitigation/TNR', 'Kitten Krewe', 'Fast Track', 'Surgery Request',
#         'Possible Owner', 'Supervisor Hold', 'Adoption Pending',
#         'Medical Treatment', 'Vet Check'], dtype=object),
#  12369,
#  count           12369
#  unique             18
#  top       New Arrival
#  freq            12241
#  Name: Initial Stage, dtype: object)

# %%
#explore initial stage and initial review date
data_df['Initial Review Date'].unique(), data_df['Initial Review Date'].notna().sum(), data_df['Initial Review Date'].describe()
# Out:
# (array([nan, '3/4/2018 5:00 PM', '5/24/2019 7:00 AM'], dtype=object),
#  2,
#  count                     2
#  unique                    2
#  top       5/24/2019 7:00 AM
#  freq                      1
#  Name: Initial Review Date, dtype: object)

# %%
#The initial stage looks interesting but initial review date is mostly null
clean_data['InitialStage'] = data_df['Initial Stage']

# %%
data_df['Pet ID'].unique()
# Out:
# array([nan])

# %%
data_df['Pet ID Type'].unique()
# Out:
# array([nan])

# %%
#all animals are released with a microchip so that information will not impact adoptions.  In addition pet id info is not used

# %%
# Review 'Status', 'Stage', 'Location', 'Sublocation','Outcome Asilomar Status'
data_df['Status'].unique(), data_df['Status'].notna().sum(), data_df['Status'].describe()
# Out:
# (array(['I', 'L', 'H', 'F'], dtype=object),
#  12372,
#  count     12372
#  unique        4
#  top           I
#  freq      12140
#  Name: Status, dtype: object)

# %%
#i'm not sure what this is and however most of the values are I so it will not be beneficial to the model

# %%
data_df['Stage'].unique(), data_df['Stage'].notna().sum(), data_df['Stage'].describe()
# Out:
# (array(['Released', 'Lost/Found', 'Licensing', 'Non Operational'],
#        dtype=object),
#  12372,
#  count        12372
#  unique           4
#  top       Released
#  freq         12301
#  Name: Stage, dtype: object)

# %%
#this appears to be the final outcome for the animal.  Given that we are looking at adoptions almost all the outcomes are released

# %%
data_df['Status'].unique(), data_df['Status'].notna().sum(), data_df['Status'].describe()
# Out:
# (array(['I', 'L', 'H', 'F'], dtype=object),
#  12372,
#  count     12372
#  unique        4
#  top           I
#  freq      12140
#  Name: Status, dtype: object)

# %%
data_df['Location'].unique(), data_df['Location'].notna().sum(), data_df['Location'].describe()
# Out:
# (array(['Released'], dtype=object),
#  12372,
#  count        12372
#  unique           1
#  top       Released
#  freq         12372
#  Name: Location, dtype: object)

# %%
data_df['Sublocation'].unique(), data_df['Sublocation'].notna().sum(), data_df['Sublocation'].describe()
# Out:
# (array([nan]),
#  0,
#  count    0.0
#  mean     NaN
#  std      NaN
#  min      NaN
#  25%      NaN
#  50%      NaN
#  75%      NaN
#  max      NaN
#  Name: Sublocation, dtype: float64)

# %%
#location and sublocation are not helpful from this file, i will need to see if i can find it separately

# %%
data_df['Outcome Asilomar Status'].unique(), data_df['Outcome Asilomar Status'].notna().sum(), data_df['Outcome Asilomar Status'].describe()
# Out:
# (array(['Treatable-Manageable', 'Treatable-Rehabilitatable', 'Healthy',
#         'Unhealthy/Untreatable', nan, 'Unassigned'], dtype=object),
#  12371,
#  count       12371
#  unique          5
#  top       Healthy
#  freq         8000
#  Name: Outcome Asilomar Status, dtype: object)

# %%
clean_data['OutcomeAsilomar'] = data_df['Outcome Asilomar Status']

# %%
data_df['Outcome Number'].unique(), data_df['Outcome Number'].notna().sum(), data_df['Outcome Number'].describe()
# Out:
# (array([ 8504,   809, 11226, ...,  2731,  2152,  2721], dtype=int64),
#  12372,
#  count    12372.000000
#  mean      5188.360734
#  std       3820.861794
#  min          1.000000
#  25%       1729.750000
#  50%       4108.000000
#  75%       7769.250000
#  max      12286.000000
#  Name: Outcome Number, dtype: float64)

# %%
data_df.columns
# Out:
# Index(['Animal #', 'ARN', 'Animal Name', 'Animal Type', 'Species',
#        'Primary Breed', 'Secondary Breed', 'Distinguishing Markings', 'Gender',
#        'Altered', 'Danger', 'Danger Reason', 'Date Of Birth',
#        'Age in Months Intake', 'Age Group', 'Intake Asilomar Status',
#        'Intake Condition', 'Intake Record Owner', 'Intake Date', 'Intake Type',
#        'Intake Subtype', 'Found Address', 'Found Zip Code', 'Reason',
#        'Intake SiteName', 'Jurisdiction In', 'Agency Name', 'Agency Member',
#        'Agency Member Phone', 'Agency Address', 'Intake Person ID',
#        'Intake Person ID Type', 'Intake Person #', 'Admitter',
#        'Street Address', 'Unit Number', 'City', 'Province', 'Postal Code',
#        'Admitter's Email', 'Admitter's Home Phone', 'Admitter's Cell Phone',
#        'Initial Stage', 'Initial Review Date', 'Age in Months Current',
#        'Microchip Issue Date', 'Microchip Provider', 'Microchip Number',
#        'Pet ID', 'Pet ID Type', 'Status', 'Stage', 'Location', 'Sublocation',
#        'Outcome Asilomar Status', 'Outcome Number', 'Released By',
#        'Date Created', 'Outcome Date', 'Release Date', 'Outcome Type',
#        'Outcome Subtype', 'Outcome SiteName', 'Jurisdiction Out',
#        'Outcome Reason', 'Outcome Person ID', 'Outcome Person ID Type',
#        'Outcome Person #', 'Outcome Person Name', 'Out Street Address',
#        'Out Unit Number', 'Out City', 'Out Province', 'Out Postal Code',
#        'Out Email', 'Out Home Phone', 'Out Cell Phone', 'Outcome Agency Name',
#        'Agency Street Address', 'Agency Unit Number', 'Agency City',
#        'Agency Province', 'Agency Postal Code', 'Agency Email',
#        'Agency Home Phone', 'Agency Cell Number', 'RN'],
#       dtype='object')

# %%
#outcome type, outcome subtype, outcome reason
data_df['Outcome Type'].unique(), data_df['Outcome Type'].notna().sum(), data_df['Outcome Type'].describe()
# Out:
# (array(['Adoption'], dtype=object),
#  12372,
#  count        12372
#  unique           1
#  top       Adoption
#  freq         12372
#  Name: Outcome Type, dtype: object)

# %%
#the outcome type is the same for all since we are only looking at adoptions
data_df['Outcome Subtype'].unique(), data_df['Outcome Subtype'].notna().sum(), data_df['Outcome Subtype'].describe()
# Out:
# (array(['Onsite', 'Foster Home/ Fast Track', 'Off-Site PetSmart',
#         'Off-Site Petco', 'Barn Cat', 'Special Event', 'Off-Site',
#         'Off-Site Clearview Volunteer', 'Off-Site Jefferson Fee',
#         'Off-Site Cat Practice', 'Off-Site Petco Kenner',
#         'Off-Site Petco Algiers', 'Off-Site Petco Mid-City',
#         'Off-Site Petco Harvey', 'Breed/Rescue',
#         'Off-Site MidCity Vet.Clinic', 'Off-Site Canine Connection',
#         'No Fleas Market', 'Offsite Petco Tchoup',
#         'Off-site PetSmart Manhattan'], dtype=object),
#  12372,
#  count      12372
#  unique        20
#  top       Onsite
#  freq        8533
#  Name: Outcome Subtype, dtype: object)

# %%
clean_data['OutcomeSubType'] = data_df['Outcome Subtype']

# %%
data_df['Outcome Reason'].unique(), data_df['Outcome Reason'].notna().sum(), data_df['Outcome Reason'].describe()
# Out:
# (array([nan]),
#  0,
#  count    0.0
#  mean     NaN
#  std      NaN
#  min      NaN
#  25%      NaN
#  50%      NaN
#  75%      NaN
#  max      NaN
#  Name: Outcome Reason, dtype: float64)

# %%
#the reason doesn't have anything.  The other fields in this file are related to the person adopting the animal which is not 
#helpful to figuring out the biggest way to get the animals adopted.  I will still need to get some additional values from
#another file.

# %%
#need to get from pure intake/outcome files
#1.prealtered
#2. size
#3.Intake location/sublocation
#4. Outcome location/sublocation
#5. Length Owned

# %%
#summarize the clean data set to see how many duplicates there are
#these animals were returned to the la-spca and adopted again.

# %%
grouped_df = clean_data.groupby('AnimalID', as_index=False).count()[['AnimalID','IntakeDate']]
grouped_df.rename(columns={'IntakeDate':'Count'}, inplace=True)
grouped_df.sort_values("Count", ascending=False)
# Out:
#         AnimalID  Count
# 2930   A31234826      5
# 9144   A40288375      4
# 6985   A37605306      4
# 6223   A36646929      4
# 2801   A31064652      4
# ...          ...    ...
# 3931   A33381229      1
# 3932   A33382904      1
# 3933   A33389041      1
# 3934   A33389443      1
# 11376  A44890302      1
#
# [11377 rows x 2 columns]

# %%
grouped_df[grouped_df['Count'] > 1]
# Out:
#         AnimalID  Count
# 6      A10356875      2
# 25     A10380452      2
# 32     A10383856      2
# 46     A13170522      2
# 61     A13971166      2
# ...          ...    ...
# 11140  A43179299      2
# 11164  A43201062      2
# 11228  A43286854      2
# 11238  A43302985      2
# 11309  A43432179      3
#
# [887 rows x 2 columns]

# %%
grouped_df[grouped_df['Count'] > 1]['Count'].sum()
# Out:
# 1882

# %%
# there are only 1882 out of 12000 adoptions where animals were returned previously.  Because I need to join this data
# to other data and id's do not exist per transaction, i'm going to exclude these from the data set
#joining the data together and then filtering them out

# %%
#merge the grouped data to the clean set
clean_data = clean_data.merge(grouped_df, on="AnimalID", how="left")
clean_data.head()
# Out:
#     AnimalID Species          PrimaryBreed      SecondaryBreed Gender  \
# 0  A10338615     Dog             Chow Chow                 Mix      M
# 1  A10345450     Dog     Poodle, Miniature                 Mix      M
# 2  A10357120     Cat    Domestic Shorthair  Domestic Shorthair      F
# 3  A10363334     Dog     Poodle, Miniature                 Mix      M
# 4  A10363778     Cat  Domestic Medium Hair  Domestic Shorthair      F
#
#          DOB          IntakeDate         OutcomeDate  IntakeAgeMonths  \
# 0 2003-07-26 2015-07-30 12:21:00 2015-08-10 10:50:00            144.0
# 1 2002-10-06 2015-06-16 15:07:00 2015-06-30 14:22:00            152.0
# 2 2007-05-13 2016-05-31 10:45:00 2016-07-25 13:13:00            108.0
# 3 2008-04-16 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0
# 4 2006-12-12 2015-03-06 10:09:00 2015-03-17 12:24:00             98.0
#
#    OutcomeAgeMonths  ... IntakeCondition                IntakeType  \
# 0        144.510611  ...        Geriatic  Owner/Guardian Surrender
# 1        152.794878  ...  Appears Normal  Owner/Guardian Surrender
# 2        110.443358  ...  Appears Normal  Owner/Guardian Surrender
# 3         85.542733  ...  Appears Normal          Seized / Custody
# 4         99.140160  ...        Geriatic  Owner/Guardian Surrender
#
#     IntakeSubType FoundZip              IntakeReason IntakeAgencyAssociation  \
# 0     Surrendered  70131.0  Health of Owner / Family                     NaN
# 1     Surrendered  70114.0             Cannot Afford                     NaN
# 2     Surrendered  70122.0                    Moving                     NaN
# 3  Stray Confined  70122.0                       NaN          Louisiana SPCA
# 4     Surrendered  70131.0                    Moving                     NaN
#
#   InitialStage            OutcomeAsilomar           OutcomeSubType Count
# 0  New Arrival       Treatable-Manageable                   Onsite     1
# 1  New Arrival  Treatable-Rehabilitatable                   Onsite     1
# 2  New Arrival                    Healthy  Foster Home/ Fast Track     1
# 3  New Arrival       Treatable-Manageable                   Onsite     1
# 4  New Arrival       Treatable-Manageable        Off-Site PetSmart     1
#
# [5 rows x 22 columns]

# %%
clean_data.rename(columns={'Count':'TimesAdopted'}, inplace=True)
clean_data.head()
# Out:
#     AnimalID Species          PrimaryBreed      SecondaryBreed Gender  \
# 0  A10338615     Dog             Chow Chow                 Mix      M
# 1  A10345450     Dog     Poodle, Miniature                 Mix      M
# 2  A10357120     Cat    Domestic Shorthair  Domestic Shorthair      F
# 3  A10363334     Dog     Poodle, Miniature                 Mix      M
# 4  A10363778     Cat  Domestic Medium Hair  Domestic Shorthair      F
#
#          DOB          IntakeDate         OutcomeDate  IntakeAgeMonths  \
# 0 2003-07-26 2015-07-30 12:21:00 2015-08-10 10:50:00            144.0
# 1 2002-10-06 2015-06-16 15:07:00 2015-06-30 14:22:00            152.0
# 2 2007-05-13 2016-05-31 10:45:00 2016-07-25 13:13:00            108.0
# 3 2008-04-16 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0
# 4 2006-12-12 2015-03-06 10:09:00 2015-03-17 12:24:00             98.0
#
#    OutcomeAgeMonths  ... IntakeCondition                IntakeType  \
# 0        144.510611  ...        Geriatic  Owner/Guardian Surrender
# 1        152.794878  ...  Appears Normal  Owner/Guardian Surrender
# 2        110.443358  ...  Appears Normal  Owner/Guardian Surrender
# 3         85.542733  ...  Appears Normal          Seized / Custody
# 4         99.140160  ...        Geriatic  Owner/Guardian Surrender
#
#     IntakeSubType FoundZip              IntakeReason IntakeAgencyAssociation  \
# 0     Surrendered  70131.0  Health of Owner / Family                     NaN
# 1     Surrendered  70114.0             Cannot Afford                     NaN
# 2     Surrendered  70122.0                    Moving                     NaN
# 3  Stray Confined  70122.0                       NaN          Louisiana SPCA
# 4     Surrendered  70131.0                    Moving                     NaN
#
#   InitialStage            OutcomeAsilomar           OutcomeSubType  \
# 0  New Arrival       Treatable-Manageable                   Onsite
# 1  New Arrival  Treatable-Rehabilitatable                   Onsite
# 2  New Arrival                    Healthy  Foster Home/ Fast Track
# 3  New Arrival       Treatable-Manageable                   Onsite
# 4  New Arrival       Treatable-Manageable        Off-Site PetSmart
#
#   TimesAdopted
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
#
# [5 rows x 22 columns]

# %%
clean_data = clean_data[clean_data['TimesAdopted'] == 1]
clean_data.shape
# Out:
# (10490, 22)

# %%
clean_data.dtypes
# Out:
# AnimalID                           object
# Species                            object
# PrimaryBreed                       object
# SecondaryBreed                     object
# Gender                             object
# DOB                        datetime64[ns]
# IntakeDate                 datetime64[ns]
# OutcomeDate                datetime64[ns]
# IntakeAgeMonths                   float64
# OutcomeAgeMonths                  float64
# AgeGroup                           object
# IntakeAsilomar                     object
# IntakeCondition                    object
# IntakeType                         object
# IntakeSubType                      object
# FoundZip                           object
# IntakeReason                       object
# IntakeAgencyAssociation            object
# InitialStage                       object
# OutcomeAsilomar                    object
# OutcomeSubType                     object
# TimesAdopted                        int64
# dtype: object

# %%
###Load Intake Only Data and get records needed

# %%
#read in files
wb = xlrd.open_workbook("Data\AnimalIntakeExtended2015_2016.xls", logfile=open(os.devnull, 'w'))
intake20152016 = pd.read_excel(wb, engine='xlrd')

wb = xlrd.open_workbook("Data\AnimalIntakeExtended2017_2018.xls", logfile=open(os.devnull, 'w'))
intake20172018 = pd.read_excel(wb, engine='xlrd')

wb = xlrd.open_workbook("Data\AnimalIntakeExtended2019.xls", logfile=open(os.devnull, 'w'))
intake2019 = pd.read_excel(wb, engine='xlrd')

#concatenate the datasets
intake_df = pd.concat([intake20152016, intake20172018, intake2019])

del intake20152016, intake20172018, intake2019

intake_df.head()
# Out:
#    Animal ID       ARN Animal Name Species               Primary Breed  \
# 0  A10323061  LA57878A       Daisy     Dog                   Dalmatian
# 1  A10331004    134141       Hazel     Dog           Terrier, Pit Bull
# 2  A10331144   la62897        Zeus     Dog                 Poodle, Toy
# 3  A10336427    221260    Clouseau     Cat          Domestic Shorthair
# 4  A10336800    281446     Diamond     Dog  Terrier, American Pit Bull
#
#       Secondary Breed Gender    Age Altered Danger  ...  Source  \
# 0                 Mix      F  16yrs      No     No  ...  Friend
# 1                 Mix      F  14yrs      No     No  ...     NaN
# 2                 Mix      M  16yrs      No     No  ...     NaN
# 3  Domestic Shorthair      M  12yrs     Yes     No  ...  Friend
# 4                 Mix      F  13yrs     Yes     No  ...     NaN
#
#         Intake Reason Length Owned   Unit Injury Type Cause     Agency Name  \
# 0  Euthanasia Request         16.0  Years         NaN   NaN             NaN
# 1                 NaN          0.0    NaN         NaN   NaN             NaN
# 2                 NaN          0.0    NaN         NaN   NaN  Louisiana SPCA
# 3               Other         10.0  Years         NaN   NaN             NaN
# 4                 NaN          0.0    NaN         NaN   NaN  Louisiana SPCA
#
#                    Location       Sub Location        Asilomar Status
# 0             Serenity Room      Serenity Room  Unhealthy/Untreatable
# 1  10 Dog Healthy Hold (Sm)               H-61   Treatable-Manageable
# 2             15 ACO Unit 5             Cage 4  Unhealthy/Untreatable
# 3         14 Shelter Clinic  14 Shelter Clinic  Unhealthy/Untreatable
# 4             15 ACO Unit 4             Cage 3   Treatable-Manageable
#
# [5 rows x 42 columns]

# %%
intake_df.shape
# Out:
# (27561, 42)

# %%
intake_df.columns
# Out:
# Index(['Animal ID', 'ARN', 'Animal Name', 'Species', 'Primary Breed',
#        'Secondary Breed', 'Gender', 'Age', 'Altered', 'Danger',
#        'Danger Reason', 'Primary Colour', 'Secondary Colour', 'Third Colour',
#        'Colour Pattern', 'Second Colour Pattern', 'Size', 'Pre Altered',
#        'Spayed Neutered', 'By', 'Record Owner', 'Intake Date/Time',
#        'Operation Type', 'Operation Sub Type', 'Pet ID', 'Pet ID Type',
#        'Location Found', 'Jurisdiction', 'Condition', 'Age Group', 'DOA',
#        'Site Name', 'Source', 'Intake Reason', 'Length Owned', 'Unit',
#        'Injury Type', 'Cause', 'Agency Name', 'Location', 'Sub Location',
#        'Asilomar Status'],
#       dtype='object')

# %%
#save all intakes for overal statistics
intake_df.to_csv('IntakeData.csv', index=False)

# %%
intake_sub = intake_df[['Animal ID', 'Intake Date/Time', 'Size', 'Length Owned', 'Unit', 'Location', 'Sub Location', 'Pre Altered']]
intake_sub = intake_sub.rename(columns={'Animal ID':'AnimalID'})
intake_sub.head()
# Out:
#     AnimalID    Intake Date/Time    Size  Length Owned   Unit  \
# 0  A10323061 2016-06-28 15:51:00  Medium          16.0  Years
# 1  A10331004 2016-03-01 12:35:00  Medium           0.0    NaN
# 2  A10331144 2016-04-20 12:13:00   Small           0.0    NaN
# 3  A10336427 2015-02-27 13:48:00   Small          10.0  Years
# 4  A10336800 2016-09-15 14:42:00   Large           0.0    NaN
#
#                    Location       Sub Location Pre Altered
# 0             Serenity Room      Serenity Room           N
# 1  10 Dog Healthy Hold (Sm)               H-61           N
# 2             15 ACO Unit 5             Cage 4           N
# 3         14 Shelter Clinic  14 Shelter Clinic           Y
# 4             15 ACO Unit 4             Cage 3           Y

# %%
newdata = clean_data.merge(intake_sub, on='AnimalID', how='left')
newdata.head()
# Out:
#     AnimalID Species        PrimaryBreed      SecondaryBreed Gender  \
# 0  A10338615     Dog           Chow Chow                 Mix      M
# 1  A10345450     Dog   Poodle, Miniature                 Mix      M
# 2  A10357120     Cat  Domestic Shorthair  Domestic Shorthair      F
# 3  A10363334     Dog   Poodle, Miniature                 Mix      M
# 4  A10363334     Dog   Poodle, Miniature                 Mix      M
#
#          DOB          IntakeDate         OutcomeDate  IntakeAgeMonths  \
# 0 2003-07-26 2015-07-30 12:21:00 2015-08-10 10:50:00            144.0
# 1 2002-10-06 2015-06-16 15:07:00 2015-06-30 14:22:00            152.0
# 2 2007-05-13 2016-05-31 10:45:00 2016-07-25 13:13:00            108.0
# 3 2008-04-16 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0
# 4 2008-04-16 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0
#
#    OutcomeAgeMonths  ...            OutcomeAsilomar           OutcomeSubType  \
# 0        144.510611  ...       Treatable-Manageable                   Onsite
# 1        152.794878  ...  Treatable-Rehabilitatable                   Onsite
# 2        110.443358  ...                    Healthy  Foster Home/ Fast Track
# 3         85.542733  ...       Treatable-Manageable                   Onsite
# 4         85.542733  ...       Treatable-Manageable                   Onsite
#
#   TimesAdopted    Intake Date/Time    Size Length Owned   Unit  \
# 0            1 2015-07-30 12:21:00  Medium         12.0  Years
# 1            1 2015-06-16 15:07:00  Medium          9.0  Years
# 2            1 2016-05-31 10:45:00   Small          9.0  Years
# 3            1 2015-03-12 11:04:00   Small          0.0    NaN
# 4            1 2015-07-26 13:27:00   Small          0.0    NaN
#
#                    Location Sub Location Pre Altered
# 0  10 Dog Healthy Hold (Sm)         H-63           Y
# 1  10 Dog Healthy Hold (Sm)         H-53           Y
# 2         04 Cat Feral Room        CF-08           Y
# 3             15 ACO Unit 4       Cage 4           Y
# 4  10 Dog Healthy Hold (Sm)         H-53           Y
#
# [5 rows x 29 columns]

# %%
newdata.shape
# Out:
# (10957, 29)

# %%
#check to see if newdata has nulls
newdata['Size'].notna().sum()

#no nulls but it looks like additional records were added
# Out:
# 10957

# %%
grouped_df = newdata.groupby('AnimalID', as_index=False).count()[['AnimalID','IntakeDate']]
grouped_df.rename(columns={'IntakeDate':'Count'}, inplace=True)
grouped_df.sort_values("Count", ascending=False)
# Out:
#         AnimalID  Count
# 5873   A36843998      6
# 8305   A40197150      5
# 8185   A40031643      5
# 3683   A33462209      4
# 7240   A38763191      4
# ...          ...    ...
# 3599   A33318279      1
# 3600   A33318285      1
# 3601   A33318293      1
# 3602   A33319961      1
# 10489  A44890302      1
#
# [10490 rows x 2 columns]

# %%
grouped_df[grouped_df['Count']>1]
# Out:
#         AnimalID  Count
# 9      A10363334      2
# 36     A11738206      2
# 47     A13625090      2
# 51     A13775490      2
# 58     A14203870      2
# ...          ...    ...
# 9967   A42766241      2
# 10069  A42917137      2
# 10177  A43059671      2
# 10223  A43131808      2
# 10358  A43308672      2
#
# [427 rows x 2 columns]

# %%
#investigate one of the id's in the intake sub set twice
intake_sub[intake_sub['AnimalID'] == 'A10363334']
# Out:
#      AnimalID    Intake Date/Time   Size  Length Owned Unit  \
# 26  A10363334 2015-03-12 11:04:00  Small           0.0  NaN
# 27  A10363334 2015-07-26 13:27:00  Small           0.0  NaN
#
#                     Location Sub Location Pre Altered
# 26             15 ACO Unit 4       Cage 4           Y
# 27  10 Dog Healthy Hold (Sm)         H-53           Y

# %%
clean_data[clean_data['AnimalID'] == 'A10363334']
# Out:
#     AnimalID Species       PrimaryBreed SecondaryBreed Gender        DOB  \
# 3  A10363334     Dog  Poodle, Miniature            Mix      M 2008-04-16
#
#            IntakeDate         OutcomeDate  IntakeAgeMonths  OutcomeAgeMonths  \
# 3 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0         85.542733
#
#    ... IntakeCondition        IntakeType   IntakeSubType FoundZip  \
# 3  ...  Appears Normal  Seized / Custody  Stray Confined  70122.0
#
#   IntakeReason IntakeAgencyAssociation InitialStage       OutcomeAsilomar  \
# 3          NaN          Louisiana SPCA  New Arrival  Treatable-Manageable
#
#   OutcomeSubType TimesAdopted
# 3         Onsite            1
#
# [1 rows x 22 columns]

# %%
#it appears that this animal ended up being returned however the outcome was not adoption so they are not listed in
#the original file.  I can create another key based on just the intake date, not time since time was sometimes different between
#seconds when I tried to match before to get the information.

# %%
clean_data['IntakeDateOnly'] = clean_data['IntakeDate'].dt.date
intake_sub['IntakeDateOnly'] = intake_sub['Intake Date/Time'].dt.date

# %%
newdata = clean_data.merge(intake_sub, on=['AnimalID', 'IntakeDateOnly'], how='left')

# %%
newdata.shape
# Out:
# (10490, 30)

# %%
#no new records created by the join
newdata['Size'].notna().sum()
# Out:
# 10490

# %%
#no nulls created - data was merged successsfully - resetting the clean data frame to be the merged data
clean_data = newdata
del newdata

# %%
clean_data.head()
# Out:
#     AnimalID Species          PrimaryBreed      SecondaryBreed Gender  \
# 0  A10338615     Dog             Chow Chow                 Mix      M
# 1  A10345450     Dog     Poodle, Miniature                 Mix      M
# 2  A10357120     Cat    Domestic Shorthair  Domestic Shorthair      F
# 3  A10363334     Dog     Poodle, Miniature                 Mix      M
# 4  A10363778     Cat  Domestic Medium Hair  Domestic Shorthair      F
#
#          DOB          IntakeDate         OutcomeDate  IntakeAgeMonths  \
# 0 2003-07-26 2015-07-30 12:21:00 2015-08-10 10:50:00            144.0
# 1 2002-10-06 2015-06-16 15:07:00 2015-06-30 14:22:00            152.0
# 2 2007-05-13 2016-05-31 10:45:00 2016-07-25 13:13:00            108.0
# 3 2008-04-16 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0
# 4 2006-12-12 2015-03-06 10:09:00 2015-03-17 12:24:00             98.0
#
#    OutcomeAgeMonths  ...           OutcomeSubType TimesAdopted IntakeDateOnly  \
# 0        144.510611  ...                   Onsite            1     2015-07-30
# 1        152.794878  ...                   Onsite            1     2015-06-16
# 2        110.443358  ...  Foster Home/ Fast Track            1     2016-05-31
# 3         85.542733  ...                   Onsite            1     2015-03-12
# 4         99.140160  ...        Off-Site PetSmart            1     2015-03-06
#
#      Intake Date/Time    Size Length Owned   Unit                  Location  \
# 0 2015-07-30 12:21:00  Medium         12.0  Years  10 Dog Healthy Hold (Sm)
# 1 2015-06-16 15:07:00  Medium          9.0  Years  10 Dog Healthy Hold (Sm)
# 2 2016-05-31 10:45:00   Small          9.0  Years         04 Cat Feral Room
# 3 2015-03-12 11:04:00   Small          0.0    NaN             15 ACO Unit 4
# 4 2015-03-06 10:09:00  Medium          5.0  Years         04 Cat Feral Room
#
#   Sub Location Pre Altered
# 0         H-63           Y
# 1         H-53           Y
# 2        CF-08           Y
# 3       Cage 4           Y
# 4        CF-17           Y
#
# [5 rows x 30 columns]

# %%
#rename some of the new fields
clean_data.rename(columns={'Length Owned':'LengthOwned', 'Unit': 'LengthOwnedUnits', 
                           'Location': 'IntakeLocation', 'Sub Location':'IntakeSubLocation', 'Pre Altered': 'PreAltered'}, inplace=True)


#drop the Intake Date/Time added by the merge
clean_data = clean_data.drop(columns='Intake Date/Time')

clean_data.head()
# Out:
#     AnimalID Species          PrimaryBreed      SecondaryBreed Gender  \
# 0  A10338615     Dog             Chow Chow                 Mix      M
# 1  A10345450     Dog     Poodle, Miniature                 Mix      M
# 2  A10357120     Cat    Domestic Shorthair  Domestic Shorthair      F
# 3  A10363334     Dog     Poodle, Miniature                 Mix      M
# 4  A10363778     Cat  Domestic Medium Hair  Domestic Shorthair      F
#
#          DOB          IntakeDate         OutcomeDate  IntakeAgeMonths  \
# 0 2003-07-26 2015-07-30 12:21:00 2015-08-10 10:50:00            144.0
# 1 2002-10-06 2015-06-16 15:07:00 2015-06-30 14:22:00            152.0
# 2 2007-05-13 2016-05-31 10:45:00 2016-07-25 13:13:00            108.0
# 3 2008-04-16 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0
# 4 2006-12-12 2015-03-06 10:09:00 2015-03-17 12:24:00             98.0
#
#    OutcomeAgeMonths  ...            OutcomeAsilomar           OutcomeSubType  \
# 0        144.510611  ...       Treatable-Manageable                   Onsite
# 1        152.794878  ...  Treatable-Rehabilitatable                   Onsite
# 2        110.443358  ...                    Healthy  Foster Home/ Fast Track
# 3         85.542733  ...       Treatable-Manageable                   Onsite
# 4         99.140160  ...       Treatable-Manageable        Off-Site PetSmart
#
#   TimesAdopted IntakeDateOnly    Size LengthOwned LengthOwnedUnits  \
# 0            1     2015-07-30  Medium        12.0            Years
# 1            1     2015-06-16  Medium         9.0            Years
# 2            1     2016-05-31   Small         9.0            Years
# 3            1     2015-03-12   Small         0.0              NaN
# 4            1     2015-03-06  Medium         5.0            Years
#
#              IntakeLocation IntakeSubLocation PreAltered
# 0  10 Dog Healthy Hold (Sm)              H-63          Y
# 1  10 Dog Healthy Hold (Sm)              H-53          Y
# 2         04 Cat Feral Room             CF-08          Y
# 3             15 ACO Unit 4            Cage 4          Y
# 4         04 Cat Feral Room             CF-17          Y
#
# [5 rows x 29 columns]

# %%
clean_data['IntakeLocation'].unique(), clean_data['IntakeLocation'].notna().sum(), clean_data['IntakeLocation'].describe()
# Out:
# (array(['10 Dog Healthy Hold (Sm)', '04 Cat Feral Room', '15 ACO Unit 4',
#         '15 ACO Unit 8', '03 Cat Healthy Hold', '15 ACO Unit 5',
#         '15 ACO Unit 1', '12 Temporary Puppy Healthy Hold',
#         '15 ACO Unit 2', '15 ACO Unit 6', '15 ACO Unit 3',
#         '08 Dog Healthy Hold (Big)', 'St. John', '14 Shelter Clinic',
#         'Puppy Healthy Hold', '05 Cat Isolation', 'Avenue Wellness Clinic',
#         'Terrebonne Parish', '02 Cat Adoptions Overflow',
#         '01 Puppy Health Hold', '24 Office', 'St Martins',
#         '09 Dog Healthy Hold (Med)', '06 Encouragement Room',
#         'Wellness Clinic', '20 Foster Care', '13 Dog Isolation',
#         'St.Charles Parish', '11 Quarantine', '25 Outside Runs',
#         '00 Cat Adoption Condo', '26 Private Vet Clinic', 'Petco Midcity',
#         '00 Temp Grooming Rm Cat Intake', '00 Placement Condos'],
#        dtype=object),
#  10490,
#  count                 10490
#  unique                   35
#  top       04 Cat Feral Room
#  freq                   3214
#  Name: IntakeLocation, dtype: object)

# %%
clean_data['IntakeSubLocation'].unique(), clean_data['IntakeSubLocation'].notna().sum(), clean_data['IntakeSubLocation'].describe()
# Out:
# (array(['H-63', 'H-53', 'CF-08', 'Cage 4', 'CF-17', 'CH-28', 'CF-04',
#         '10 Dog Healthy Hold (Sm)', 'Cage 5', 'Cage 2', 'H-58', 'CF-07',
#         'H-56', 'H-54', 'CF-02', 'H-52', 'CT-03', 'Cage 3', 'H-55',
#         'CT-04', 'CF-06', 'H-57', 'CT-02', 'Cage 1', 'H-61', 'H-60',
#         'CF-12', 'CF-03', 'CT-01', 'CF-18', 'CF-01', 'CT-05',
#         '08 Dog Healthy Hold (Big)', '03 Cat Healthy Hold', 'CH-21',
#         'H-62', 'CF-15', 'CF-11', 'CF-13', 'CF-10', '12 Cat Temp',
#         'Cage 6', 'St John', 'CH-16', 'CF-05', 'CH-42', 'CH-34', 'CH-41',
#         'CH-37', 'CH-32', 'CH-33', 'CH-38', 'CH-39', 'CH-31', 'CH-35',
#         '14 Shelter Clinic', 'CF-14', 'H-59', 'CH-20', 'CT-06', 'PH-03',
#         'PH-04', 'PH-06', 'CI-04', 'CF-16', 'Wellness Clinic',
#         'Terrebonne Parish', 'CH-24', '04 Cat Feral Room',
#         '02 Cat Adoptions', 'H-01', 'H-02', '01 Puppy hh', 'CH-07',
#         '24 Office', 'CH-29', 'CH-27', 'CF-09', 'CH-01', 'CA-22', 'CA-02',
#         'CH-22', 'CH-36', 'CH-06', 'CH-08', 'CH-04', 'CI-03', 'CI-02',
#         'CH-19', 'H-16', 'CA-29', 'CH-09', 'St Martins', 'PHH-18', 'H-03',
#         'H-24', 'CI-10', 'CI-08', 'H-30', 'PHH-01',
#         '09 Dog Healthy Hold (Med)', 'CA-10', 'PHH-05', 'H-15', 'H-13',
#         'PHH-06', 'H-42', '00 Encouragement ', 'CI-05', 'CI-07', 'CH-03',
#         'CA-13', 'H-07', 'H-05', 'CH-43', 'PH-01', 'H-28', 'CH-30',
#         'CA-07', 'V-03', '20 Foster Care', 'CA-37', 'Encouragement - 02',
#         'H-06', 'CA-33', 'PHH-04', 'PHH-14', 'PI-07', 'I-08', 'H-45',
#         'PHH-13', 'H-23', 'St.Charles Parish', 'PHH-21', 'H-17', 'PHH-09',
#         'H-04', 'H-09', 'CA-17', 'Q-01', 'Encouragement - 06',
#         'Encouragement - 07', 'H-44', 'H-08', 'CA-01', 'PHH-25', 'PHH-08',
#         '25 Outside Runs', 'PHH-02', 'I-04', 'PHH-10', 'PHH-16', 'CH-25',
#         'CH-15', 'H-10', 'H-33', 'H-19', 'PH-22', 'PH-07', 'H-14', 'CC-04',
#         'PHH-03', '26 Private Vet Clinic', 'CC-05', 'H-22', 'PHH-07',
#         'CH-18', 'CH-23', 'CH-05', 'CH-10', 'PHH-12', 'Encouragement - 03',
#         'Encouragement - 01', 'CH-40', 'CH-13', 'Petco Midcity', 'CH-02',
#         'GI-05', 'GI-03', 'GI-04', 'GI-06', 'GI-01', 'GI-08', 'H-21',
#         'H-20', 'CH-11', 'PHH-24', 'Cat Condo', 'EPC - 03', 'H-12',
#         'EPC - 01 ', 'EPC - 02', '00 Encouragement PC', 'Q-05', 'CH-17'],
#        dtype=object),
#  10490,
#  count      10490
#  unique       195
#  top       Cage 2
#  freq         748
#  Name: IntakeSubLocation, dtype: object)

# %%
###Load Outcome Only Data and get records needed

# %%
#read in files
wb = xlrd.open_workbook("Data\AnimalOutcomebyIntakeExtended2015_2016.xls", logfile=open(os.devnull, 'w'))
outcome20152016 = pd.read_excel(wb, engine='xlrd')

wb = xlrd.open_workbook("Data\AnimalOutcomebyIntakeExtended2017_2018.xls", logfile=open(os.devnull, 'w'))
outcome20172018 = pd.read_excel(wb, engine='xlrd')

wb = xlrd.open_workbook("Data\AnimalOutcomebyIntakeExtended2019_2020.xls", logfile=open(os.devnull, 'w'))
outcome2019 = pd.read_excel(wb, engine='xlrd')

#concatenate the datasets
outcome_df = pd.concat([outcome20152016, outcome20172018, outcome2019])

del outcome20152016, outcome20172018, outcome2019

outcome_df.head()
# Out:
#     Animal #       ARN  Animal Name Species         Primary Breed  \
# 0  A10338615  LA54918A         Chaz     Dog             Chow Chow
# 1  A10345450  LA54552A     Snowball     Dog     Poodle, Miniature
# 2  A10357120  LA57609A  Louise (Lu)     Cat    Domestic Shorthair
# 3  A10363334  LA54952A        Lucky     Dog     Poodle, Miniature
# 4  A10363778   LA34139         Zoey     Cat  Domestic Medium Hair
#
#              Colors  Gender Altered Pre-Altered      Chip Number  ...  \
# 0            Black/    Male     Yes         Yes  982000362192682  ...
# 1            Cream/    Male     Yes         Yes       0A102E7808  ...
# 2  White/Grey/Black  Female     Yes         Yes  982000406897769  ...
# 3            White/    Male     Yes         Yes       4a7d4c3664  ...
# 4        Grey/Brown  Female     Yes         Yes       4b05703d73  ...
#
#            Outcome Subtype Outcome Site           Outcome Location  \
# 0                   Onsite   LA Shelter  09 Dog Healthy Hold (Med)
# 1                   Onsite   LA Shelter       01 Puppy Health Hold
# 2  Foster Home/ Fast Track   LA Shelter             20 Foster Care
# 3                   Onsite   LA Shelter  08 Dog Healthy Hold (Big)
# 4        Off-Site PetSmart   LA Shelter              PetSmart N.O.
#
#   Outcome Sublocation Outcome Jurisdiction Transfer Out Reason Outcome Agency  \
# 0                H-44                70124                 NaN            NaN
# 1              PHH-04                70126                 NaN            NaN
# 2      20 Foster Care                70119                 NaN            NaN
# 3                H-17                70113                 NaN            NaN
# 4       PetSmart N.O.                70115                 NaN            NaN
#
#           Released By            Release Date LOS
# 0     Vanessa Artigas 2015-08-10 10:50:56.000  10
# 1  Greyshelneka Lewis 2015-06-30 14:22:58.077  13
# 2    Sheila Hernandez 2016-07-25 13:13:21.000  55
# 3     Vanessa Artigas 2015-06-02 15:41:11.000  82
# 4       Tonya LeJeune 2015-03-17 12:24:29.620  11
#
# [5 rows x 44 columns]

# %%
outcome_df.columns
# Out:
# Index(['Animal #', 'ARN', 'Animal Name', 'Species', 'Primary Breed', 'Colors',
#        'Gender', 'Altered', 'Pre-Altered', 'Chip Number', 'Chip Provider',
#        'Danger', 'Danger Reason', 'Date of Birth', 'Intake Age', 'Intake By',
#        'Intake Date', 'Intake Type', 'Intake Subtype', 'Intake Reason',
#        'Intake Site', 'Intake Location', 'Intake Sublocation',
#        'Intake Jurisdiction', 'Intake Condition', 'Intake Agency',
#        'Agency Member', 'Agency Member Phone', 'Agency Address', 'Outcome Age',
#        'Outcome Age in Months', 'Outcome Date', 'Outcome By', 'Outcome Type',
#        'Outcome Subtype', 'Outcome Site', 'Outcome Location',
#        'Outcome Sublocation', 'Outcome Jurisdiction', 'Transfer Out Reason',
#        'Outcome Agency', 'Released By', 'Release Date', 'LOS'],
#       dtype='object')

# %%
outcome_df.shape
# Out:
# (13001, 44)

# %%
#save complete outcome data
outcome_df.to_csv("OutcomeData.csv", index=False)

# %%
#need to create subset of data to merge and outcome date keys to merge datasets on
outcome_sub = outcome_df[['Animal #', 'Outcome Date', 'Outcome Location', 'Outcome Sublocation']]
outcome_sub = outcome_sub.rename(columns={'Animal #':'AnimalID', 'Outcome Location':'OutcomeLocation', 
                           'Outcome Sublocation': 'OutcomeSubLocation'})

outcome_sub['OutcomeDateOnly'] = outcome_sub['Outcome Date'].dt.date
clean_data['OutcomeDateOnly'] = clean_data['OutcomeDate'].dt.date

#drop the outcome date from the subset
outcome_sub = outcome_sub.drop(columns='Outcome Date')

newdata = clean_data.merge(outcome_sub, on=['AnimalID', 'OutcomeDateOnly'], how="left")

newdata.head()
# Out:
#     AnimalID Species          PrimaryBreed      SecondaryBreed Gender  \
# 0  A10338615     Dog             Chow Chow                 Mix      M
# 1  A10345450     Dog     Poodle, Miniature                 Mix      M
# 2  A10357120     Cat    Domestic Shorthair  Domestic Shorthair      F
# 3  A10363334     Dog     Poodle, Miniature                 Mix      M
# 4  A10363778     Cat  Domestic Medium Hair  Domestic Shorthair      F
#
#          DOB          IntakeDate         OutcomeDate  IntakeAgeMonths  \
# 0 2003-07-26 2015-07-30 12:21:00 2015-08-10 10:50:00            144.0
# 1 2002-10-06 2015-06-16 15:07:00 2015-06-30 14:22:00            152.0
# 2 2007-05-13 2016-05-31 10:45:00 2016-07-25 13:13:00            108.0
# 3 2008-04-16 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0
# 4 2006-12-12 2015-03-06 10:09:00 2015-03-17 12:24:00             98.0
#
#    OutcomeAgeMonths  ... IntakeDateOnly    Size LengthOwned LengthOwnedUnits  \
# 0        144.510611  ...     2015-07-30  Medium        12.0            Years
# 1        152.794878  ...     2015-06-16  Medium         9.0            Years
# 2        110.443358  ...     2016-05-31   Small         9.0            Years
# 3         85.542733  ...     2015-03-12   Small         0.0              NaN
# 4         99.140160  ...     2015-03-06  Medium         5.0            Years
#
#              IntakeLocation IntakeSubLocation PreAltered OutcomeDateOnly  \
# 0  10 Dog Healthy Hold (Sm)              H-63          Y      2015-08-10
# 1  10 Dog Healthy Hold (Sm)              H-53          Y      2015-06-30
# 2         04 Cat Feral Room             CF-08          Y      2016-07-25
# 3             15 ACO Unit 4            Cage 4          Y      2015-06-02
# 4         04 Cat Feral Room             CF-17          Y      2015-03-17
#
#              OutcomeLocation OutcomeSubLocation
# 0  09 Dog Healthy Hold (Med)               H-44
# 1       01 Puppy Health Hold             PHH-04
# 2             20 Foster Care     20 Foster Care
# 3  08 Dog Healthy Hold (Big)               H-17
# 4              PetSmart N.O.      PetSmart N.O.
#
# [5 rows x 32 columns]

# %%
newdata.shape
# Out:
# (10491, 32)

# %%
#it created one extra record
newdata['OutcomeLocation'].notna().sum()
# Out:
# 10491

# %%
#no nulls
#investigate duplicate record
grouped_df = newdata.groupby('AnimalID', as_index=False).count()[['AnimalID','OutcomeDate']]
grouped_df.rename(columns={'OutcomeDate':'Count'}, inplace=True)
grouped_df.sort_values("Count", ascending=False)
# Out:
#         AnimalID  Count
# 10221  A43120087      2
# 0      A10336599      1
# 6987   A38461967      1
# 6989   A38462485      1
# 6990   A38462521      1
# ...          ...    ...
# 3498   A33188235      1
# 3499   A33191445      1
# 3500   A33198184      1
# 3501   A33199261      1
# 10489  A44890302      1
#
# [10490 rows x 2 columns]

# %%
#view duplicated record
outcome_sub[outcome_sub['AnimalID']=='A43120087']
# Out:
#        AnimalID        OutcomeLocation OutcomeSubLocation OutcomeDateOnly
# 2487  A43120087  00 Cat Adoption Condo          Cat Condo      2020-02-09
# 2488  A43120087         20 Foster Care     20 Foster Care      2020-02-09

# %%
outcome_df[outcome_df['Animal #']=='A43120087'][['Animal #', 'Outcome Date']]
# Out:
#        Animal #        Outcome Date
# 2487  A43120087 2020-02-09 16:59:00
# 2488  A43120087 2020-02-09 12:28:00

# %%
outcome_df[outcome_df['Animal #']=='A43120087'][['Animal #', 'Intake Date', 'Outcome Date']]
# Out:
#        Animal #             Intake Date        Outcome Date
# 2487  A43120087 2020-02-09 15:11:45.247 2020-02-09 16:59:00
# 2488  A43120087 2019-10-31 11:08:30.320 2020-02-09 12:28:00

# %%
#THis animal was initially adopted in 2019 but was not returned until 2020.  I need to exclude any intake dates
#from before 1/1/2020.  I need to filter the original data and recreate the subset.

outcome_df = outcome_df[pd.to_datetime(outcome_df['Intake Date']) < pd.Timestamp(2020,1,1)]
outcome_df.shape
# Out:
# (12852, 44)

# %%
#need to create subset of data to merge and outcome date keys to merge datasets on
outcome_sub = outcome_df[['Animal #', 'Outcome Date', 'Outcome Location', 'Outcome Sublocation']]
outcome_sub = outcome_sub.rename(columns={'Animal #':'AnimalID', 'Outcome Location':'OutcomeLocation', 
                           'Outcome Sublocation': 'OutcomeSubLocation'})

outcome_sub['OutcomeDateOnly'] = outcome_sub['Outcome Date'].dt.date
clean_data['OutcomeDateOnly'] = clean_data['OutcomeDate'].dt.date

#drop the outcome date from the subset
outcome_sub = outcome_sub.drop(columns='Outcome Date')

newdata = clean_data.merge(outcome_sub, on=['AnimalID', 'OutcomeDateOnly'], how="left")

newdata.head()
# Out:
#     AnimalID Species          PrimaryBreed      SecondaryBreed Gender  \
# 0  A10338615     Dog             Chow Chow                 Mix      M
# 1  A10345450     Dog     Poodle, Miniature                 Mix      M
# 2  A10357120     Cat    Domestic Shorthair  Domestic Shorthair      F
# 3  A10363334     Dog     Poodle, Miniature                 Mix      M
# 4  A10363778     Cat  Domestic Medium Hair  Domestic Shorthair      F
#
#          DOB          IntakeDate         OutcomeDate  IntakeAgeMonths  \
# 0 2003-07-26 2015-07-30 12:21:00 2015-08-10 10:50:00            144.0
# 1 2002-10-06 2015-06-16 15:07:00 2015-06-30 14:22:00            152.0
# 2 2007-05-13 2016-05-31 10:45:00 2016-07-25 13:13:00            108.0
# 3 2008-04-16 2015-03-12 11:03:00 2015-06-02 15:41:00             82.0
# 4 2006-12-12 2015-03-06 10:09:00 2015-03-17 12:24:00             98.0
#
#    OutcomeAgeMonths  ... IntakeDateOnly    Size LengthOwned LengthOwnedUnits  \
# 0        144.510611  ...     2015-07-30  Medium        12.0            Years
# 1        152.794878  ...     2015-06-16  Medium         9.0            Years
# 2        110.443358  ...     2016-05-31   Small         9.0            Years
# 3         85.542733  ...     2015-03-12   Small         0.0              NaN
# 4         99.140160  ...     2015-03-06  Medium         5.0            Years
#
#              IntakeLocation IntakeSubLocation PreAltered OutcomeDateOnly  \
# 0  10 Dog Healthy Hold (Sm)              H-63          Y      2015-08-10
# 1  10 Dog Healthy Hold (Sm)              H-53          Y      2015-06-30
# 2         04 Cat Feral Room             CF-08          Y      2016-07-25
# 3             15 ACO Unit 4            Cage 4          Y      2015-06-02
# 4         04 Cat Feral Room             CF-17          Y      2015-03-17
#
#              OutcomeLocation OutcomeSubLocation
# 0  09 Dog Healthy Hold (Med)               H-44
# 1       01 Puppy Health Hold             PHH-04
# 2             20 Foster Care     20 Foster Care
# 3  08 Dog Healthy Hold (Big)               H-17
# 4              PetSmart N.O.      PetSmart N.O.
#
# [5 rows x 32 columns]

# %%
newdata.shape
# Out:
# (10490, 32)

# %%
newdata['OutcomeLocation'].notna().sum()
# Out:
# 10490

# %%
#looks good.  I'm going to save the clean data in a csv to use in R for some exploratory data analysis
clean_data = newdata
clean_data.to_csv('CleanData.csv', index=False)

# %%
#read in and combine euthanasia stats for use in general statistics
wb = xlrd.open_workbook("Data\AnimalIntakeWithResultsExtended_Euth_2015_2016.xlsx", logfile=open(os.devnull, 'w'))
euth20152016 = pd.read_excel(wb, engine='xlrd')

wb = xlrd.open_workbook("Data\AnimalIntakeWithResultsExtended_Euth_2017_2018.xlsx", logfile=open(os.devnull, 'w'))
euth20172018 = pd.read_excel(wb, engine='xlrd')

wb = xlrd.open_workbook("Data\AnimalIntakeWithResultsExtended_Euth_2019_2020.xlsx", logfile=open(os.devnull, 'w'))
euth2019 = pd.read_excel(wb, engine='xlrd')

#concatenate the datasets
euth_df = pd.concat([euth20152016, euth20172018, euth2019])

del euth20152016, euth20172018, euth2019

euth_df.head()
# Out:
#     Animal #       ARN Animal Name Animal Type Species  \
# 0  A10323061  LA57878A       Daisy         Dog     Dog
# 1  A10331144   la62897        Zeus         Dog     Dog
# 2  A10336427    221260    Clouseau         Cat     Cat
# 3  A10336800    281446     Diamond         Dog     Dog
# 4  A10340450   LA52217         ACE         Dog     Dog
#
#                 Primary Breed     Secondary Breed Distinguishing Markings  \
# 0                   Dalmatian                 Mix                     NaN
# 1                 Poodle, Toy                 Mix                     NaN
# 2          Domestic Shorthair  Domestic Shorthair                     NaN
# 3  Terrier, American Pit Bull                 Mix                     NaN
# 4           Terrier, Pit Bull                 NaN                     NaN
#
#   Gender Altered  ... Outcome Agency Name Agency Street Address  \
# 0      F      No  ...                 NaN                   NaN
# 1      M      No  ...                 NaN                   NaN
# 2      M     Yes  ...                 NaN                   NaN
# 3      F     Yes  ...                 NaN                   NaN
# 4      M      No  ...                 NaN                   NaN
#
#   Agency Unit Number  Agency City Agency Province Agency Postal Code  \
# 0                NaN          NaN             NaN                NaN
# 1                NaN          NaN             NaN                NaN
# 2                NaN          NaN             NaN                NaN
# 3                NaN          NaN             NaN                NaN
# 4                NaN          NaN             NaN                NaN
#
#   Agency Email Agency Home Phone Agency Cell Number RN
# 0          NaN               NaN                NaN  1
# 1          NaN               NaN                NaN  1
# 2          NaN               NaN                NaN  1
# 3          NaN               NaN                NaN  1
# 4          NaN               NaN                NaN  1
#
# [5 rows x 87 columns]

# %%
euth_df.shape
# Out:
# (5690, 87)

# %%
euth_df.to_csv('EuthData.csv', index=False)
